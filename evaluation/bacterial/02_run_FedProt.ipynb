# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/ /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 01-Jun-24 18:56:38 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 01-Jun-24 18:56:38 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 01-Jun-24 18:56:38 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 01-Jun-24 18:56:38 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 01-Jun-24 18:56:38 - rpy2.situation - INFO - R library path:
# 01-Jun-24 18:56:38 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 01-Jun-24 18:56:38 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 01-Jun-24 18:56:38 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 01-Jun-24 18:56:38 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 01-Jun-24 18:56:38 - root - INFO - Number of arguments: 6
# ...

# %% [markdown]
# # Imbalanced

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ imbalanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 01-Jun-24 18:56:45 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 01-Jun-24 18:56:45 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 01-Jun-24 18:56:45 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 01-Jun-24 18:56:45 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 01-Jun-24 18:56:46 - rpy2.situation - INFO - R library path:
# 01-Jun-24 18:56:46 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 01-Jun-24 18:56:46 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 01-Jun-24 18:56:46 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 01-Jun-24 18:56:46 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 01-Jun-24 18:56:46 - root - INFO - Number of arguments: 6
# ...

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ downsampled lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 01-Jun-24 18:56:52 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 01-Jun-24 18:56:52 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 01-Jun-24 18:56:52 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 01-Jun-24 18:56:52 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 01-Jun-24 18:56:53 - rpy2.situation - INFO - R library path:
# 01-Jun-24 18:56:53 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 01-Jun-24 18:56:53 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 01-Jun-24 18:56:53 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 01-Jun-24 18:56:53 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 01-Jun-24 18:56:53 - root - INFO - Number of arguments: 6
# ...
