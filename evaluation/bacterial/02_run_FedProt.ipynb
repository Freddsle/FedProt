# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/ /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 17-May-24 21:30:37 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 17-May-24 21:30:37 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 17-May-24 21:30:37 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 17-May-24 21:30:37 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 17-May-24 21:30:37 - rpy2.situation - INFO - R library path:
# 17-May-24 21:30:37 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 17-May-24 21:30:37 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 17-May-24 21:30:37 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 17-Mai-24 21:30:37 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 17-Mai-24 21:30:37 - root - INFO - Number of arguments: 6
# 17-Mai-24 21:30:37 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//balanced
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A: Using counts.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A: 24 samples are kept.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A: Loaded 24 samples and 2548 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B: Using counts.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B: 23 samples are kept.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B: Loaded 23 samples and 2846 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C: Using counts.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C: 23 samples are kept.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C: Loaded 23 samples and 2819 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D: Using counts.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D: 24 samples are kept.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D: Loaded 24 samples and 2813 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_E: Using counts.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_E: 24 samples are kept.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 17-Mai-24 21:30:37 - root - INFO - SERVER: Common proteins: 2273
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Protein groups are validated.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Validated 24 samples and 2273 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Samples in lab_A data: 24
# 17-Mai-24 21:30:37 - root - INFO - Protein groups in lab_A data:  2273
# 17-Mai-24 21:30:37 - root - INFO - Design lab_A has beed updated with cohort effects
# 17-Mai-24 21:30:37 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Protein groups are validated.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Validated 23 samples and 2273 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Samples in lab_B data: 23
# 17-Mai-24 21:30:37 - root - INFO - Protein groups in lab_B data:  2273
# 17-Mai-24 21:30:37 - root - INFO - Design lab_B has beed updated with cohort effects
# 17-Mai-24 21:30:37 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Protein groups are validated.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Validated 23 samples and 2273 proteins.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 17-Mai-24 21:30:37 - root - INFO - Samples in lab_C data: 23
# 17-Mai-24 21:30:37 - root - INFO - Protein groups in lab_C data:  2273
# 17-Mai-24 21:30:37 - root - INFO - Design lab_C has beed updated with cohort effects
# 17-Mai-24 21:30:37 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D:	Protein groups are validated.
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 17-Mai-24 21:30:37 - root - INFO - Client lab_D:	Validated 24 samples and 2273 proteins.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_D data: 24
# 17-Mai-24 21:30:38 - root - INFO - Protein groups in lab_D data:  2273
# 17-Mai-24 21:30:38 - root - INFO - Design lab_D has beed updated with cohort effects
# 17-Mai-24 21:30:38 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Protein groups are validated.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Validated 24 samples and 2273 proteins.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_E data: 24
# 17-Mai-24 21:30:38 - root - INFO - Protein groups in lab_E data:  2273
# 17-Mai-24 21:30:38 - root - INFO - Design lab_E has beed updated with cohort effects
# 17-Mai-24 21:30:38 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 17-Mai-24 21:30:38 - root - INFO - SERVER: Proteins after filtering: 2272
# 17-Mai-24 21:30:38 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2232
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_A data: 24, protein groups: 2232
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_B data: 23, protein groups: 2232
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_C data: 23, protein groups: 2232
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_D data: 24, protein groups: 2232
# 17-Mai-24 21:30:38 - root - INFO - Samples in lab_E data: 24, protein groups: 2232
# 17-Mai-24 21:30:38 - root - INFO - Start computing XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - XtX and XtY have been computed for lab_A
# 17-Mai-24 21:30:38 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 17-Mai-24 21:30:38 - root - INFO - Start computing XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - XtX and XtY have been computed for lab_B
# 17-Mai-24 21:30:38 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 17-Mai-24 21:30:38 - root - INFO - Start computing XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - XtX and XtY have been computed for lab_C
# 17-Mai-24 21:30:38 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 17-Mai-24 21:30:38 - root - INFO - Start computing XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - XtX and XtY have been computed for lab_D
# 17-Mai-24 21:30:38 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 17-Mai-24 21:30:38 - root - INFO - Start computing XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - XtX and XtY have been computed for lab_E
# 17-Mai-24 21:30:38 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 17-Mai-24 21:30:38 - root - INFO - SERVER: Number of proteins: 2232, number of variables: 6
# 17-Mai-24 21:30:38 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 17-Mai-24 21:30:38 - root - INFO - SERVER: XtX and XtY have been aggregated
# 17-Mai-24 21:30:38 - root - INFO - SERVER: Computing beta and stdev
# 17-Mai-24 21:30:38 - root - INFO - Start computation of SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - SSE and cov_coef have been computed for lab_A
# 17-Mai-24 21:30:38 - root - INFO - Start computation of SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - SSE and cov_coef have been computed for lab_B
# 17-Mai-24 21:30:38 - root - INFO - Start computation of SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - SSE and cov_coef have been computed for lab_C
# 17-Mai-24 21:30:38 - root - INFO - Start computation of SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - SSE and cov_coef have been computed for lab_D
# 17-Mai-24 21:30:38 - root - INFO - Start computation of SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - SSE and cov_coef have been computed for lab_E
# 17-Mai-24 21:30:38 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 17-Mai-24 21:30:38 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 17-Mai-24 21:30:38 - root - INFO - Making contrasts...
# 17-Mai-24 21:30:38 - root - INFO - Fit contrasts...
# 17-Mai-24 21:30:38 - root - INFO - .... orthogonality of design matrix is False
# 17-Mai-24 21:30:38 - root - INFO - Start eBays stage...
# 17-Mai-24 21:30:38 - root - INFO - "Result table is pre-computed...
# 17-Mai-24 21:30:38 - root - INFO - Computing B statistic...
# 17-Mai-24 21:30:39 - root - INFO - Calculating tail p-values
# 17-Mai-24 21:30:40 - root - INFO - B statistic has been computed...
# 17-Mai-24 21:30:40 - root - INFO - Computing p-values...
# 17-Mai-24 21:30:40 - root - INFO - P-values have been computed...
# 17-Mai-24 21:30:40 - root - INFO - Min counts have been computed...
# 17-Mai-24 21:30:40 - root - INFO - Min counts have been aggregated...
# 17-Mai-24 21:30:40 - root - INFO - Size of global min counts: (2232,)
# 17-Mai-24 21:30:40 - root - INFO - Start spectral count eBayes stage...
# 17-Mai-24 21:30:40 - root - INFO - Fitting LOWESS curve...
# 17-Mai-24 21:30:40 - root - INFO - min_count: (2232,), log_var: (2232,)
# 17-Mai-24 21:30:41 - root - INFO - Spectral count eBayes stage is done...
# 17-Mai-24 21:30:41 - root - INFO - Writing results...
# 17-Mai-24 21:30:41 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial//balanced/results/DPE.csv

# %% [markdown]
# # Imbalanced

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ imbalanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 20-May-24 22:34:48 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 20-May-24 22:34:48 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 20-May-24 22:34:48 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 20-May-24 22:34:48 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 20-May-24 22:34:48 - rpy2.situation - INFO - R library path:
# 20-May-24 22:34:48 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 20-May-24 22:34:48 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 20-May-24 22:34:48 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 20-Mai-24 22:34:48 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 20-Mai-24 22:34:48 - root - INFO - Number of arguments: 6
# 20-Mai-24 22:34:48 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//imbalanced
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A: Using counts.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A: 8 samples are kept.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A: Loaded 8 samples and 2546 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B: Using counts.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B: 14 samples are kept.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B: Loaded 14 samples and 2844 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C: Using counts.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C: 17 samples are kept.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C: Loaded 17 samples and 2814 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D: Using counts.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D: 7 samples are kept.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D: Loaded 7 samples and 2811 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E: Using counts.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E: 24 samples are kept.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:48 - root - INFO - SERVER: Common proteins: 2273
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been aggregated...
# 20-Mai-24 22:34:48 - root - INFO - Size of global min counts: (2273,)
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Protein groups are validated.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Validated 8 samples and 2273 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Samples in lab_A data: 8
# 20-Mai-24 22:34:48 - root - INFO - Protein groups in lab_A data:  2273
# 20-Mai-24 22:34:48 - root - INFO - Design lab_A has beed updated with cohort effects
# 20-Mai-24 22:34:48 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Protein groups are validated.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Validated 14 samples and 2273 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Samples in lab_B data: 14
# 20-Mai-24 22:34:48 - root - INFO - Protein groups in lab_B data:  2273
# 20-Mai-24 22:34:48 - root - INFO - Design lab_B has beed updated with cohort effects
# 20-Mai-24 22:34:48 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Protein groups are validated.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Validated 17 samples and 2273 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Samples in lab_C data: 17
# 20-Mai-24 22:34:48 - root - INFO - Protein groups in lab_C data:  2273
# 20-Mai-24 22:34:48 - root - INFO - Design lab_C has beed updated with cohort effects
# 20-Mai-24 22:34:48 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Protein groups are validated.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Validated 7 samples and 2273 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Samples in lab_D data: 7
# 20-Mai-24 22:34:48 - root - INFO - Protein groups in lab_D data:  2273
# 20-Mai-24 22:34:48 - root - INFO - Design lab_D has beed updated with cohort effects
# 20-Mai-24 22:34:48 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Protein groups are validated.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Validated 24 samples and 2273 proteins.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:48 - root - INFO - Samples in lab_E data: 24
# 20-Mai-24 22:34:48 - root - INFO - Protein groups in lab_E data:  2273
# 20-Mai-24 22:34:48 - root - INFO - Design lab_E has beed updated with cohort effects
# 20-Mai-24 22:34:48 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:48 - root - INFO - CLIENT: Filters have been applied...
# 20-Mai-24 22:34:48 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:49 - root - INFO - SERVER: Proteins after filtering: 2271
# 20-Mai-24 22:34:49 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2234
# 20-Mai-24 22:34:49 - root - INFO - Samples in lab_A data: 8, protein groups: 2234
# 20-Mai-24 22:34:49 - root - INFO - Samples in lab_B data: 14, protein groups: 2234
# 20-Mai-24 22:34:49 - root - INFO - Samples in lab_C data: 17, protein groups: 2234
# 20-Mai-24 22:34:49 - root - INFO - Samples in lab_D data: 7, protein groups: 2234
# 20-Mai-24 22:34:49 - root - INFO - Samples in lab_E data: 24, protein groups: 2234
# 20-Mai-24 22:34:49 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - XtX and XtY have been computed for lab_A
# 20-Mai-24 22:34:49 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:49 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - XtX and XtY have been computed for lab_B
# 20-Mai-24 22:34:49 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:49 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - XtX and XtY have been computed for lab_C
# 20-Mai-24 22:34:49 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:49 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - XtX and XtY have been computed for lab_D
# 20-Mai-24 22:34:49 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:49 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - XtX and XtY have been computed for lab_E
# 20-Mai-24 22:34:49 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:49 - root - INFO - SERVER: Number of proteins: 2234, number of variables: 6
# 20-Mai-24 22:34:49 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 20-Mai-24 22:34:49 - root - INFO - SERVER: XtX and XtY have been aggregated
# 20-Mai-24 22:34:49 - root - INFO - SERVER: Computing beta and stdev
# 20-Mai-24 22:34:49 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - SSE and cov_coef have been computed for lab_A
# 20-Mai-24 22:34:49 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - SSE and cov_coef have been computed for lab_B
# 20-Mai-24 22:34:49 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - SSE and cov_coef have been computed for lab_C
# 20-Mai-24 22:34:49 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - SSE and cov_coef have been computed for lab_D
# 20-Mai-24 22:34:49 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - SSE and cov_coef have been computed for lab_E
# 20-Mai-24 22:34:49 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 20-Mai-24 22:34:49 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 20-Mai-24 22:34:49 - root - INFO - Making contrasts...
# 20-Mai-24 22:34:49 - root - INFO - Fit contrasts...
# 20-Mai-24 22:34:49 - root - INFO - .... orthogonality of design matrix is False
# 20-Mai-24 22:34:49 - root - INFO - Start eBays stage...
# 20-Mai-24 22:34:49 - root - INFO - "Result table is pre-computed...
# 20-Mai-24 22:34:49 - root - INFO - Computing B statistic...
# 20-Mai-24 22:34:50 - root - INFO - Calculating tail p-values
# 20-Mai-24 22:34:51 - root - INFO - B statistic has been computed...
# 20-Mai-24 22:34:51 - root - INFO - Computing p-values...
# 20-Mai-24 22:34:51 - root - INFO - P-values have been computed...
# 20-Mai-24 22:34:51 - root - INFO - Size of global min counts: (2234,)
# 20-Mai-24 22:34:51 - root - INFO - Start spectral count eBayes stage...
# 20-Mai-24 22:34:51 - root - INFO - Fitting LOWESS curve...
# 20-Mai-24 22:34:51 - root - INFO - min_count: (2234,), log_var: (2234,)
# 20-Mai-24 22:34:52 - root - INFO - Spectral count eBayes stage is done...
# 20-Mai-24 22:34:52 - root - INFO - Writing results...
# 20-Mai-24 22:34:52 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/imbalanced/results/DPE.csv

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ downsampled lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 20-May-24 22:34:53 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 20-May-24 22:34:53 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 20-May-24 22:34:53 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 20-May-24 22:34:53 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 20-May-24 22:34:54 - rpy2.situation - INFO - R library path:
# 20-May-24 22:34:54 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 20-May-24 22:34:54 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 20-May-24 22:34:54 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 20-Mai-24 22:34:54 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 20-Mai-24 22:34:54 - root - INFO - Number of arguments: 6
# 20-Mai-24 22:34:54 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//downsampled
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A: Using counts.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A: 14 samples are kept.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A: Loaded 14 samples and 2547 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B: Using counts.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B: 14 samples are kept.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B: Loaded 14 samples and 2844 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C: Using counts.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C: 14 samples are kept.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C: Loaded 14 samples and 2817 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D: Using counts.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D: 14 samples are kept.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D: Loaded 14 samples and 2813 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E: Using counts.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E: 14 samples are kept.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E: Loaded 14 samples and 2400 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - SERVER: Common proteins: 2272
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been aggregated...
# 20-Mai-24 22:34:54 - root - INFO - Size of global min counts: (2272,)
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Protein groups are validated.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Validated 14 samples and 2272 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_A data: 14
# 20-Mai-24 22:34:54 - root - INFO - Protein groups in lab_A data:  2272
# 20-Mai-24 22:34:54 - root - INFO - Design lab_A has beed updated with cohort effects
# 20-Mai-24 22:34:54 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Protein groups are validated.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Validated 14 samples and 2272 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_B data: 14
# 20-Mai-24 22:34:54 - root - INFO - Protein groups in lab_B data:  2272
# 20-Mai-24 22:34:54 - root - INFO - Design lab_B has beed updated with cohort effects
# 20-Mai-24 22:34:54 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Protein groups are validated.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Validated 14 samples and 2272 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_C data: 14
# 20-Mai-24 22:34:54 - root - INFO - Protein groups in lab_C data:  2272
# 20-Mai-24 22:34:54 - root - INFO - Design lab_C has beed updated with cohort effects
# 20-Mai-24 22:34:54 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Protein groups are validated.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Validated 14 samples and 2272 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_D data: 14
# 20-Mai-24 22:34:54 - root - INFO - Protein groups in lab_D data:  2272
# 20-Mai-24 22:34:54 - root - INFO - Design lab_D has beed updated with cohort effects
# 20-Mai-24 22:34:54 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Protein groups are validated.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Validated 14 samples and 2272 proteins.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_E data: 14
# 20-Mai-24 22:34:54 - root - INFO - Protein groups in lab_E data:  2272
# 20-Mai-24 22:34:54 - root - INFO - Design lab_E has beed updated with cohort effects
# 20-Mai-24 22:34:54 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Mai-24 22:34:54 - root - INFO - CLIENT: Filters have been applied...
# 20-Mai-24 22:34:54 - root - INFO - Min counts have been computed...
# 20-Mai-24 22:34:54 - root - INFO - SERVER: Proteins after filtering: 2271
# 20-Mai-24 22:34:54 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2232
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_A data: 14, protein groups: 2232
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_B data: 14, protein groups: 2232
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_C data: 14, protein groups: 2232
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_D data: 14, protein groups: 2232
# 20-Mai-24 22:34:54 - root - INFO - Samples in lab_E data: 14, protein groups: 2232
# 20-Mai-24 22:34:54 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:54 - root - INFO - XtX and XtY have been computed for lab_A
# 20-Mai-24 22:34:54 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:54 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:54 - root - INFO - XtX and XtY have been computed for lab_B
# 20-Mai-24 22:34:54 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:54 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:55 - root - INFO - XtX and XtY have been computed for lab_C
# 20-Mai-24 22:34:55 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:55 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:55 - root - INFO - XtX and XtY have been computed for lab_D
# 20-Mai-24 22:34:55 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:55 - root - INFO - Start computing XtX and XtY
# 20-Mai-24 22:34:55 - root - INFO - XtX and XtY have been computed for lab_E
# 20-Mai-24 22:34:55 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Mai-24 22:34:55 - root - INFO - SERVER: Number of proteins: 2232, number of variables: 6
# 20-Mai-24 22:34:55 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 20-Mai-24 22:34:55 - root - INFO - SERVER: XtX and XtY have been aggregated
# 20-Mai-24 22:34:55 - root - INFO - SERVER: Computing beta and stdev
# 20-Mai-24 22:34:55 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - SSE and cov_coef have been computed for lab_A
# 20-Mai-24 22:34:55 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - SSE and cov_coef have been computed for lab_B
# 20-Mai-24 22:34:55 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - SSE and cov_coef have been computed for lab_C
# 20-Mai-24 22:34:55 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - SSE and cov_coef have been computed for lab_D
# 20-Mai-24 22:34:55 - root - INFO - Start computation of SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - SSE and cov_coef have been computed for lab_E
# 20-Mai-24 22:34:55 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 20-Mai-24 22:34:55 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 20-Mai-24 22:34:55 - root - INFO - Making contrasts...
# 20-Mai-24 22:34:55 - root - INFO - Fit contrasts...
# 20-Mai-24 22:34:55 - root - INFO - .... orthogonality of design matrix is False
# 20-Mai-24 22:34:55 - root - INFO - Start eBays stage...
# 20-Mai-24 22:34:55 - root - INFO - "Result table is pre-computed...
# 20-Mai-24 22:34:55 - root - INFO - Computing B statistic...
# 20-Mai-24 22:34:56 - root - INFO - Calculating tail p-values
# 20-Mai-24 22:34:56 - root - INFO - B statistic has been computed...
# 20-Mai-24 22:34:56 - root - INFO - Computing p-values...
# 20-Mai-24 22:34:56 - root - INFO - P-values have been computed...
# 20-Mai-24 22:34:56 - root - INFO - Size of global min counts: (2232,)
# 20-Mai-24 22:34:56 - root - INFO - Start spectral count eBayes stage...
# 20-Mai-24 22:34:56 - root - INFO - Fitting LOWESS curve...
# 20-Mai-24 22:34:56 - root - INFO - min_count: (2232,), log_var: (2232,)
# 20-Mai-24 22:34:57 - root - INFO - Spectral count eBayes stage is done...
# 20-Mai-24 22:34:57 - root - INFO - Writing results...
# 20-Mai-24 22:34:57 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/downsampled/results/DPE.csv
