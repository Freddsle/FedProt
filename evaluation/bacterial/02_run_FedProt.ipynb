# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/ /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 27-May-24 19:54:02 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 27-May-24 19:54:02 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 27-May-24 19:54:02 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 27-May-24 19:54:02 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 27-May-24 19:54:03 - rpy2.situation - INFO - R library path:
# 27-May-24 19:54:03 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 27-May-24 19:54:03 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 27-May-24 19:54:03 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 27-Mai-24 19:54:03 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 27-Mai-24 19:54:03 - root - INFO - Number of arguments: 6
# 27-Mai-24 19:54:03 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//balanced
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Using counts.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Rows will be affected : 1
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: 24 samples are kept.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_A: Loaded 24 samples and 2548 proteins.
# 27-Mai-24 19:54:03 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Using counts.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Rows will be affected : 0
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: 23 samples are kept.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_B: Loaded 23 samples and 2846 proteins.
# 27-Mai-24 19:54:03 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:03 - root - INFO - Client lab_C: Using counts.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_C: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:03 - root - INFO - Client lab_C: Rows will be affected : 1
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C: 23 samples are kept.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C: Loaded 23 samples and 2819 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Using counts.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Rows will be affected : 0
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: 24 samples are kept.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D: Loaded 24 samples and 2813 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Using counts.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Rows will be affected : 0
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: 24 samples are kept.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:04 - root - INFO - SERVER: Common proteins: 3058
# 27-Mai-24 19:54:04 - root - INFO - Min counts have been aggregated...
# 27-Mai-24 19:54:04 - root - INFO - Size of global min counts: (3058,)
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Some protein groups are not in the client list: 510 and will be added.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Protein groups are validated.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Validated 24 samples and 3058 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Collinearity will be checked.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_A data: 24
# 27-Mai-24 19:54:04 - root - INFO - Protein groups in lab_A data:  3058
# 27-Mai-24 19:54:04 - root - INFO - Design lab_A has beed updated with cohort effects
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Some protein groups are not in the client list: 212 and will be added.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Protein groups are validated.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Validated 23 samples and 3058 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_B data: 23
# 27-Mai-24 19:54:04 - root - INFO - Protein groups in lab_B data:  3058
# 27-Mai-24 19:54:04 - root - INFO - Design lab_B has beed updated with cohort effects
# 27-Mai-24 19:54:04 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Some protein groups are not in the client list: 239 and will be added.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Protein groups are validated.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Validated 23 samples and 3058 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_C data: 23
# 27-Mai-24 19:54:04 - root - INFO - Protein groups in lab_C data:  3058
# 27-Mai-24 19:54:04 - root - INFO - Design lab_C has beed updated with cohort effects
# 27-Mai-24 19:54:04 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Some protein groups are not in the client list: 245 and will be added.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Protein groups are validated.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Validated 24 samples and 3058 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_D data: 24
# 27-Mai-24 19:54:04 - root - INFO - Protein groups in lab_D data:  3058
# 27-Mai-24 19:54:04 - root - INFO - Design lab_D has beed updated with cohort effects
# 27-Mai-24 19:54:04 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Some protein groups are not in the client list: 657 and will be added.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Protein groups are validated.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Validated 24 samples and 3058 proteins.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_E data: 24
# 27-Mai-24 19:54:04 - root - INFO - Protein groups in lab_E data:  3058
# 27-Mai-24 19:54:04 - root - INFO - Design lab_E has beed updated with cohort effects
# 27-Mai-24 19:54:04 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:04 - root - INFO - CLIENT: Filters have been applied...
# 27-Mai-24 19:54:04 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:04 - root - INFO - SERVER: Proteins after filtering: 2862
# 27-Mai-24 19:54:04 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2862
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_A data: 24, protein groups: 2862
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_B data: 23, protein groups: 2862
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_C data: 23, protein groups: 2862
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_D data: 24, protein groups: 2862
# 27-Mai-24 19:54:04 - root - INFO - Samples in lab_E data: 24, protein groups: 2862
# 27-Mai-24 19:54:04 - root - INFO - Client lab_A:	Prepared for limma. Samples: 24, Proteins: 2862.
# 27-Mai-24 19:54:05 - root - INFO - Client lab_B:	Prepared for limma. Samples: 23, Proteins: 2862.
# 27-Mai-24 19:54:05 - root - INFO - Client lab_C:	Prepared for limma. Samples: 23, Proteins: 2862.
# 27-Mai-24 19:54:05 - root - INFO - Client lab_D:	Prepared for limma. Samples: 24, Proteins: 2862.
# 27-Mai-24 19:54:05 - root - INFO - Client lab_E:	Prepared for limma. Samples: 24, Proteins: 2862.
# 27-Mai-24 19:54:05 - root - INFO - SERVER: Number of proteins: 2862, number of variables: 6
# 27-Mai-24 19:54:05 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:06 - root - INFO - Client lab_A:	Collinearity check and update completed.
# 27-Mai-24 19:54:06 - root - INFO - Client lab_A:	Collinearity check completed.
# 27-Mai-24 19:54:06 - root - INFO - Client lab_B:	Collinearity check completed.
# 27-Mai-24 19:54:06 - root - INFO - Client lab_C:	Collinearity check completed.
# 27-Mai-24 19:54:06 - root - INFO - Client lab_D:	Collinearity check completed.
# 27-Mai-24 19:54:06 - root - INFO - Client lab_E:	Collinearity check completed.
# 27-Mai-24 19:54:06 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:06 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - XtX and XtY have been computed for lab_A
# 27-Mai-24 19:54:06 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:06 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - XtX and XtY have been computed for lab_B
# 27-Mai-24 19:54:06 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:06 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - XtX and XtY have been computed for lab_C
# 27-Mai-24 19:54:06 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:06 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - XtX and XtY have been computed for lab_D
# 27-Mai-24 19:54:06 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:06 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - XtX and XtY have been computed for lab_E
# 27-Mai-24 19:54:06 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:06 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 27-Mai-24 19:54:06 - root - INFO - SERVER: XtX and XtY have been aggregated
# 27-Mai-24 19:54:06 - root - INFO - SERVER: Computing beta and stdev
# 27-Mai-24 19:54:07 - root - INFO - Detected partial NA coefficients for 569 probe(s).
# 27-Mai-24 19:54:07 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - SSE and cov_coef have been computed for lab_A
# 27-Mai-24 19:54:07 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - SSE and cov_coef have been computed for lab_B
# 27-Mai-24 19:54:07 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - SSE and cov_coef have been computed for lab_C
# 27-Mai-24 19:54:07 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - SSE and cov_coef have been computed for lab_D
# 27-Mai-24 19:54:07 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - SSE and cov_coef have been computed for lab_E
# 27-Mai-24 19:54:07 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 27-Mai-24 19:54:07 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 27-Mai-24 19:54:07 - root - INFO - Making contrasts...
# 27-Mai-24 19:54:07 - root - INFO - Fit contrasts...
# 27-Mai-24 19:54:07 - root - INFO - .... orthogonality of design matrix is False
# 27-Mai-24 19:54:07 - root - INFO - Start eBays stage...
# 27-Mai-24 19:54:07 - root - INFO - "Result table is pre-computed...
# 27-Mai-24 19:54:07 - root - INFO - Computing B statistic...
# 27-Mai-24 19:54:08 - root - INFO - Calculating tail p-values
# 27-Mai-24 19:54:08 - root - INFO - B statistic has been computed...
# 27-Mai-24 19:54:08 - root - INFO - Computing p-values...
# 27-Mai-24 19:54:08 - root - INFO - P-values have been computed...
# 27-Mai-24 19:54:08 - root - INFO - Size of global min counts: (2862,)
# 27-Mai-24 19:54:08 - root - INFO - Start spectral count eBayes stage...
# 27-Mai-24 19:54:08 - root - INFO - Fitting LOWESS curve...
# 27-Mai-24 19:54:08 - root - INFO - min_count: (2862,), log_var: (2862,)
# 27-Mai-24 19:54:10 - root - INFO - Spectral count eBayes stage is done...
# 27-Mai-24 19:54:10 - root - INFO - Writing results...
# 27-Mai-24 19:54:10 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial//balanced/results/DPE.csv

# %% [markdown]
# # Imbalanced

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ imbalanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 27-May-24 19:54:11 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 27-May-24 19:54:11 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 27-May-24 19:54:11 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 27-May-24 19:54:11 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 27-May-24 19:54:11 - rpy2.situation - INFO - R library path:
# 27-May-24 19:54:11 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 27-May-24 19:54:11 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 27-May-24 19:54:11 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 27-Mai-24 19:54:11 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 27-Mai-24 19:54:11 - root - INFO - Number of arguments: 6
# 27-Mai-24 19:54:11 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//imbalanced
# 27-Mai-24 19:54:11 - root - INFO - Client lab_A: Using counts.
# 27-Mai-24 19:54:11 - root - INFO - Client lab_A: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:11 - root - INFO - Client lab_A: Rows will be affected : 1
# 27-Mai-24 19:54:12 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_A: 15 samples are kept.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_A: Loaded 15 samples and 2547 proteins.
# 27-Mai-24 19:54:12 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Using counts.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Rows will be affected : 1
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: 19 samples are kept.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_B: Loaded 19 samples and 2845 proteins.
# 27-Mai-24 19:54:12 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Using counts.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Rows will be affected : 6
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: 13 samples are kept.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_C: Loaded 13 samples and 2811 proteins.
# 27-Mai-24 19:54:12 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Using counts.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Rows will be affected : 0
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: 21 samples are kept.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_D: Loaded 21 samples and 2813 proteins.
# 27-Mai-24 19:54:12 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:12 - root - INFO - Client lab_E: Using counts.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_E: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:12 - root - INFO - Client lab_E: Rows will be affected : 0
# 27-Mai-24 19:54:12 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E: 18 samples are kept.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E: Loaded 18 samples and 2401 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:13 - root - INFO - SERVER: Common proteins: 3056
# 27-Mai-24 19:54:13 - root - INFO - Min counts have been aggregated...
# 27-Mai-24 19:54:13 - root - INFO - Size of global min counts: (3056,)
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Some protein groups are not in the client list: 509 and will be added.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Protein groups are validated.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Validated 15 samples and 3056 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Collinearity will be checked.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_A data: 15
# 27-Mai-24 19:54:13 - root - INFO - Protein groups in lab_A data:  3056
# 27-Mai-24 19:54:13 - root - INFO - Design lab_A has beed updated with cohort effects
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Some protein groups are not in the client list: 211 and will be added.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Protein groups are validated.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Validated 19 samples and 3056 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_B data: 19
# 27-Mai-24 19:54:13 - root - INFO - Protein groups in lab_B data:  3056
# 27-Mai-24 19:54:13 - root - INFO - Design lab_B has beed updated with cohort effects
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Some protein groups are not in the client list: 245 and will be added.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Protein groups are validated.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Validated 13 samples and 3056 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_C data: 13
# 27-Mai-24 19:54:13 - root - INFO - Protein groups in lab_C data:  3056
# 27-Mai-24 19:54:13 - root - INFO - Design lab_C has beed updated with cohort effects
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Some protein groups are not in the client list: 243 and will be added.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Protein groups are validated.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Validated 21 samples and 3056 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_D data: 21
# 27-Mai-24 19:54:13 - root - INFO - Protein groups in lab_D data:  3056
# 27-Mai-24 19:54:13 - root - INFO - Design lab_D has beed updated with cohort effects
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Some protein groups are not in the client list: 655 and will be added.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Protein groups are validated.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Validated 18 samples and 3056 proteins.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_E data: 18
# 27-Mai-24 19:54:13 - root - INFO - Protein groups in lab_E data:  3056
# 27-Mai-24 19:54:13 - root - INFO - Design lab_E has beed updated with cohort effects
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:13 - root - INFO - CLIENT: Filters have been applied...
# 27-Mai-24 19:54:13 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:13 - root - INFO - SERVER: Proteins after filtering: 2860
# 27-Mai-24 19:54:13 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2860
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_A data: 15, protein groups: 2860
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_B data: 19, protein groups: 2860
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_C data: 13, protein groups: 2860
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_D data: 21, protein groups: 2860
# 27-Mai-24 19:54:13 - root - INFO - Samples in lab_E data: 18, protein groups: 2860
# 27-Mai-24 19:54:13 - root - INFO - Client lab_A:	Prepared for limma. Samples: 15, Proteins: 2860.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_B:	Prepared for limma. Samples: 19, Proteins: 2860.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_C:	Prepared for limma. Samples: 13, Proteins: 2860.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_D:	Prepared for limma. Samples: 21, Proteins: 2860.
# 27-Mai-24 19:54:13 - root - INFO - Client lab_E:	Prepared for limma. Samples: 18, Proteins: 2860.
# 27-Mai-24 19:54:14 - root - INFO - SERVER: Number of proteins: 2860, number of variables: 6
# 27-Mai-24 19:54:14 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:15 - root - INFO - Client lab_A:	Collinearity check and update completed.
# 27-Mai-24 19:54:15 - root - INFO - Client lab_A:	Collinearity check completed.
# 27-Mai-24 19:54:15 - root - INFO - Client lab_B:	Collinearity check completed.
# 27-Mai-24 19:54:15 - root - INFO - Client lab_C:	Collinearity check completed.
# 27-Mai-24 19:54:15 - root - INFO - Client lab_D:	Collinearity check completed.
# 27-Mai-24 19:54:15 - root - INFO - Client lab_E:	Collinearity check completed.
# 27-Mai-24 19:54:15 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:15 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - XtX and XtY have been computed for lab_A
# 27-Mai-24 19:54:15 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:15 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - XtX and XtY have been computed for lab_B
# 27-Mai-24 19:54:15 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:15 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - XtX and XtY have been computed for lab_C
# 27-Mai-24 19:54:15 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:15 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - XtX and XtY have been computed for lab_D
# 27-Mai-24 19:54:15 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:15 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - XtX and XtY have been computed for lab_E
# 27-Mai-24 19:54:15 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:15 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 27-Mai-24 19:54:15 - root - INFO - SERVER: XtX and XtY have been aggregated
# 27-Mai-24 19:54:15 - root - INFO - SERVER: Computing beta and stdev
# 27-Mai-24 19:54:15 - root - INFO - Detected partial NA coefficients for 532 probe(s).
# 27-Mai-24 19:54:15 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:15 - root - INFO - SSE and cov_coef have been computed for lab_A
# 27-Mai-24 19:54:15 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:15 - root - INFO - SSE and cov_coef have been computed for lab_B
# 27-Mai-24 19:54:15 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:16 - root - INFO - SSE and cov_coef have been computed for lab_C
# 27-Mai-24 19:54:16 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:16 - root - INFO - SSE and cov_coef have been computed for lab_D
# 27-Mai-24 19:54:16 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:16 - root - INFO - SSE and cov_coef have been computed for lab_E
# 27-Mai-24 19:54:16 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 27-Mai-24 19:54:16 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 27-Mai-24 19:54:16 - root - INFO - Making contrasts...
# 27-Mai-24 19:54:16 - root - INFO - Fit contrasts...
# 27-Mai-24 19:54:16 - root - INFO - .... orthogonality of design matrix is False
# 27-Mai-24 19:54:16 - root - INFO - Start eBays stage...
# 27-Mai-24 19:54:16 - root - INFO - "Result table is pre-computed...
# 27-Mai-24 19:54:16 - root - INFO - Computing B statistic...
# 27-Mai-24 19:54:17 - root - INFO - Calculating tail p-values
# 27-Mai-24 19:54:17 - root - INFO - B statistic has been computed...
# 27-Mai-24 19:54:17 - root - INFO - Computing p-values...
# 27-Mai-24 19:54:17 - root - INFO - P-values have been computed...
# 27-Mai-24 19:54:17 - root - INFO - Size of global min counts: (2860,)
# 27-Mai-24 19:54:17 - root - INFO - Start spectral count eBayes stage...
# 27-Mai-24 19:54:17 - root - INFO - Fitting LOWESS curve...
# 27-Mai-24 19:54:17 - root - INFO - min_count: (2860,), log_var: (2860,)
# 27-Mai-24 19:54:18 - root - INFO - Spectral count eBayes stage is done...
# 27-Mai-24 19:54:18 - root - INFO - Writing results...
# 27-Mai-24 19:54:19 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/imbalanced/results/DPE.csv

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ downsampled lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 27-May-24 19:54:20 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 27-May-24 19:54:20 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 27-May-24 19:54:20 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 27-May-24 19:54:20 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 27-May-24 19:54:20 - rpy2.situation - INFO - R library path:
# 27-May-24 19:54:20 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 27-May-24 19:54:20 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 27-May-24 19:54:20 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 27-Mai-24 19:54:20 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 27-Mai-24 19:54:20 - root - INFO - Number of arguments: 6
# 27-Mai-24 19:54:20 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//downsampled
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Using counts.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Rows will be affected : 2
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: 18 samples are kept.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_A: Loaded 18 samples and 2547 proteins.
# 27-Mai-24 19:54:21 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Using counts.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Rows will be affected : 1
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: 16 samples are kept.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_B: Loaded 16 samples and 2844 proteins.
# 27-Mai-24 19:54:21 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Using counts.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Rows will be affected : 7
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: 16 samples are kept.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_C: Loaded 16 samples and 2813 proteins.
# 27-Mai-24 19:54:21 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Using counts.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Rows will be affected : 0
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: 18 samples are kept.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_D: Loaded 18 samples and 2813 proteins.
# 27-Mai-24 19:54:21 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:21 - root - INFO - Client lab_E: Using counts.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_E: Replacing rows with only one non-NA value with NA.
# 27-Mai-24 19:54:21 - root - INFO - Client lab_E: Rows will be affected : 1
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E: 18 samples are kept.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E: Loaded 18 samples and 2400 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:22 - root - INFO - SERVER: Common proteins: 3054
# 27-Mai-24 19:54:22 - root - INFO - Min counts have been aggregated...
# 27-Mai-24 19:54:22 - root - INFO - Size of global min counts: (3054,)
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Some protein groups are not in the client list: 507 and will be added.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Protein groups are validated.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Validated 18 samples and 3054 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Collinearity will be checked.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_A data: 18
# 27-Mai-24 19:54:22 - root - INFO - Protein groups in lab_A data:  3054
# 27-Mai-24 19:54:22 - root - INFO - Design lab_A has beed updated with cohort effects
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Some protein groups are not in the client list: 210 and will be added.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Protein groups are validated.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Validated 16 samples and 3054 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_B data: 16
# 27-Mai-24 19:54:22 - root - INFO - Protein groups in lab_B data:  3054
# 27-Mai-24 19:54:22 - root - INFO - Design lab_B has beed updated with cohort effects
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Some protein groups are not in the client list: 241 and will be added.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Protein groups are validated.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Validated 16 samples and 3054 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_C data: 16
# 27-Mai-24 19:54:22 - root - INFO - Protein groups in lab_C data:  3054
# 27-Mai-24 19:54:22 - root - INFO - Design lab_C has beed updated with cohort effects
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Some protein groups are not in the client list: 241 and will be added.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Protein groups are validated.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Validated 18 samples and 3054 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_D data: 18
# 27-Mai-24 19:54:22 - root - INFO - Protein groups in lab_D data:  3054
# 27-Mai-24 19:54:22 - root - INFO - Design lab_D has beed updated with cohort effects
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Some protein groups are not in the client list: 654 and will be added.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Protein groups are validated.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	1 columns are excluded from the design matrix: {'lab'}
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Validated 18 samples and 3054 proteins.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_E data: 18
# 27-Mai-24 19:54:22 - root - INFO - Protein groups in lab_E data:  3054
# 27-Mai-24 19:54:22 - root - INFO - Design lab_E has beed updated with cohort effects
# 27-Mai-24 19:54:22 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 27-Mai-24 19:54:22 - root - INFO - CLIENT: Filters have been applied...
# 27-Mai-24 19:54:22 - root - INFO - Min counts have been computed...
# 27-Mai-24 19:54:22 - root - INFO - SERVER: Proteins after filtering: 2859
# 27-Mai-24 19:54:22 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2859
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_A data: 18, protein groups: 2859
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_B data: 16, protein groups: 2859
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_C data: 16, protein groups: 2859
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_D data: 18, protein groups: 2859
# 27-Mai-24 19:54:22 - root - INFO - Samples in lab_E data: 18, protein groups: 2859
# 27-Mai-24 19:54:22 - root - INFO - Client lab_A:	Prepared for limma. Samples: 18, Proteins: 2859.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_B:	Prepared for limma. Samples: 16, Proteins: 2859.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_C:	Prepared for limma. Samples: 16, Proteins: 2859.
# 27-Mai-24 19:54:22 - root - INFO - Client lab_D:	Prepared for limma. Samples: 18, Proteins: 2859.
# 27-Mai-24 19:54:23 - root - INFO - Client lab_E:	Prepared for limma. Samples: 18, Proteins: 2859.
# 27-Mai-24 19:54:23 - root - INFO - SERVER: Number of proteins: 2859, number of variables: 6
# 27-Mai-24 19:54:23 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:24 - root - INFO - Client lab_A:	Collinearity check and update completed.
# 27-Mai-24 19:54:24 - root - INFO - Client lab_A:	Collinearity check completed.
# 27-Mai-24 19:54:24 - root - INFO - Client lab_B:	Collinearity check completed.
# 27-Mai-24 19:54:24 - root - INFO - Client lab_C:	Collinearity check completed.
# 27-Mai-24 19:54:24 - root - INFO - Client lab_D:	Collinearity check completed.
# 27-Mai-24 19:54:24 - root - INFO - Client lab_E:	Collinearity check completed.
# 27-Mai-24 19:54:24 - root - INFO - SMPC is not used, aggregating masks
# 27-Mai-24 19:54:24 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - XtX and XtY have been computed for lab_A
# 27-Mai-24 19:54:24 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:24 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - XtX and XtY have been computed for lab_B
# 27-Mai-24 19:54:24 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:24 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - XtX and XtY have been computed for lab_C
# 27-Mai-24 19:54:24 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:24 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - XtX and XtY have been computed for lab_D
# 27-Mai-24 19:54:24 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:24 - root - INFO - Start computing XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - XtX and XtY have been computed for lab_E
# 27-Mai-24 19:54:24 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 27-Mai-24 19:54:24 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 27-Mai-24 19:54:24 - root - INFO - SERVER: XtX and XtY have been aggregated
# 27-Mai-24 19:54:24 - root - INFO - SERVER: Computing beta and stdev
# 27-Mai-24 19:54:25 - root - INFO - Detected partial NA coefficients for 569 probe(s).
# 27-Mai-24 19:54:25 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - SSE and cov_coef have been computed for lab_A
# 27-Mai-24 19:54:25 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - SSE and cov_coef have been computed for lab_B
# 27-Mai-24 19:54:25 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - SSE and cov_coef have been computed for lab_C
# 27-Mai-24 19:54:25 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - SSE and cov_coef have been computed for lab_D
# 27-Mai-24 19:54:25 - root - INFO - Start computation of SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - SSE and cov_coef have been computed for lab_E
# 27-Mai-24 19:54:25 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 27-Mai-24 19:54:25 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 27-Mai-24 19:54:25 - root - INFO - Making contrasts...
# 27-Mai-24 19:54:25 - root - INFO - Fit contrasts...
# 27-Mai-24 19:54:25 - root - INFO - .... orthogonality of design matrix is False
# 27-Mai-24 19:54:25 - root - INFO - Start eBays stage...
# 27-Mai-24 19:54:25 - root - INFO - "Result table is pre-computed...
# 27-Mai-24 19:54:25 - root - INFO - Computing B statistic...
# 27-Mai-24 19:54:26 - root - INFO - Calculating tail p-values
# 27-Mai-24 19:54:27 - root - INFO - B statistic has been computed...
# 27-Mai-24 19:54:27 - root - INFO - Computing p-values...
# 27-Mai-24 19:54:27 - root - INFO - P-values have been computed...
# 27-Mai-24 19:54:27 - root - INFO - Size of global min counts: (2859,)
# 27-Mai-24 19:54:27 - root - INFO - Start spectral count eBayes stage...
# 27-Mai-24 19:54:27 - root - INFO - Fitting LOWESS curve...
# 27-Mai-24 19:54:27 - root - INFO - min_count: (2859,), log_var: (2859,)
# 27-Mai-24 19:54:28 - root - INFO - Spectral count eBayes stage is done...
# 27-Mai-24 19:54:28 - root - INFO - Writing results...
# 27-Mai-24 19:54:28 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/downsampled/results/DPE.csv
