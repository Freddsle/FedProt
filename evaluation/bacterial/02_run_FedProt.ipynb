# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/ /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/analysed_proteins.json
# Out:
# 20-Jul-24 23:23:42 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 20-Jul-24 23:23:42 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 20-Jul-24 23:23:42 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/deqms_fed/lib/R
# 20-Jul-24 23:23:42 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/deqms_fed/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 20-Jul-24 23:23:42 - rpy2.situation - INFO - R library path:
# 20-Jul-24 23:23:42 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 20-Jul-24 23:23:42 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 20-Jul-24 23:23:42 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 20-Jul-24 23:23:42 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 20-Jul-24 23:23:42 - root - INFO - Number of arguments: 6
# 20-Jul-24 23:23:42 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//balanced
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Using counts.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Skipping the replacement of rows with only one non-NA value with NA.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 20-Jul-24 23:23:42 - root - WARNING - Client lab_A: Intensities contain samples that are not in design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: 20 samples are kept.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Skipping the removal of rows with less than 2 non-NA values.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A: Loaded 20 samples and 2549 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Using counts.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Skipping the replacement of rows with only one non-NA value with NA.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 20-Jul-24 23:23:42 - root - WARNING - Client lab_B: Intensities contain samples that are not in design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: 19 samples are kept.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Skipping the removal of rows with less than 2 non-NA values.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B: Loaded 19 samples and 2846 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Using counts.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Skipping the replacement of rows with only one non-NA value with NA.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: 23 samples are kept.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Skipping the removal of rows with less than 2 non-NA values.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C: Loaded 23 samples and 2820 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Using counts.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Skipping the replacement of rows with only one non-NA value with NA.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 20-Jul-24 23:23:42 - root - WARNING - Client lab_D: Intensities contain samples that are not in design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: 20 samples are kept.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Skipping the removal of rows with less than 2 non-NA values.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D: Loaded 20 samples and 2813 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Using counts.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Skipping the replacement of rows with only one non-NA value with NA.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 20-Jul-24 23:23:42 - root - WARNING - Client lab_E: Intensities contain samples that are not in design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: 20 samples are kept.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Skipping the removal of rows with less than 2 non-NA values.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E: Loaded 20 samples and 2401 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:42 - root - INFO - SERVER: Common proteins: 3059
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been aggregated...
# 20-Jul-24 23:23:42 - root - INFO - Size of global min counts: (3059,)
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Some protein groups are not in the client list: 510 and will be added.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Protein groups are validated.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Validated 20 samples and 3059 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Collinearity will be checked.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Samples in lab_A data: 20
# 20-Jul-24 23:23:42 - root - INFO - Protein groups in lab_A data:  3059
# 20-Jul-24 23:23:42 - root - INFO - Design lab_A has beed updated with cohort effects
# 20-Jul-24 23:23:42 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Some protein groups are not in the client list: 213 and will be added.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Protein groups are validated.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Validated 19 samples and 3059 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Samples in lab_B data: 19
# 20-Jul-24 23:23:42 - root - INFO - Protein groups in lab_B data:  3059
# 20-Jul-24 23:23:42 - root - INFO - Design lab_B has beed updated with cohort effects
# 20-Jul-24 23:23:42 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Some protein groups are not in the client list: 239 and will be added.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Protein groups are validated.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Validated 23 samples and 3059 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Samples in lab_C data: 23
# 20-Jul-24 23:23:42 - root - INFO - Protein groups in lab_C data:  3059
# 20-Jul-24 23:23:42 - root - INFO - Design lab_C has beed updated with cohort effects
# 20-Jul-24 23:23:42 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Some protein groups are not in the client list: 246 and will be added.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Protein groups are validated.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Validated 20 samples and 3059 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Samples in lab_D data: 20
# 20-Jul-24 23:23:42 - root - INFO - Protein groups in lab_D data:  3059
# 20-Jul-24 23:23:42 - root - INFO - Design lab_D has beed updated with cohort effects
# 20-Jul-24 23:23:42 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Some protein groups are not in the client list: 658 and will be added.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Protein groups are validated.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Validated 20 samples and 3059 proteins.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 20-Jul-24 23:23:42 - root - INFO - Samples in lab_E data: 20
# 20-Jul-24 23:23:42 - root - INFO - Protein groups in lab_E data:  3059
# 20-Jul-24 23:23:42 - root - INFO - Design lab_E has beed updated with cohort effects
# 20-Jul-24 23:23:42 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 20-Jul-24 23:23:42 - root - INFO - CLIENT: Filters have been applied...
# 20-Jul-24 23:23:42 - root - INFO - Min counts have been computed...
# 20-Jul-24 23:23:43 - root - INFO - SERVER: Proteins after filtering: 2831
# 20-Jul-24 23:23:43 - root - INFO - SERVER: Proteins after filtering FOR EVALUATION: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_A: Updating counts.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_A: Protein groups: 2831, Counts shape: (3059,)
# 20-Jul-24 23:23:43 - root - INFO - Samples in lab_A data: 20, protein groups: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_B: Updating counts.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_B: Protein groups: 2831, Counts shape: (3059,)
# 20-Jul-24 23:23:43 - root - INFO - Samples in lab_B data: 19, protein groups: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_C: Updating counts.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_C: Protein groups: 2831, Counts shape: (3059,)
# 20-Jul-24 23:23:43 - root - INFO - Samples in lab_C data: 23, protein groups: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_D: Updating counts.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_D: Protein groups: 2831, Counts shape: (3059,)
# 20-Jul-24 23:23:43 - root - INFO - Samples in lab_D data: 20, protein groups: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_E: Updating counts.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_E: Protein groups: 2831, Counts shape: (3059,)
# 20-Jul-24 23:23:43 - root - INFO - Samples in lab_E data: 20, protein groups: 2831
# 20-Jul-24 23:23:43 - root - INFO - Client lab_A:	Prepared for limma. Samples: 20, Proteins: 2831.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_B:	Prepared for limma. Samples: 19, Proteins: 2831.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_C:	Prepared for limma. Samples: 23, Proteins: 2831.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_D:	Prepared for limma. Samples: 20, Proteins: 2831.
# 20-Jul-24 23:23:43 - root - INFO - Client lab_E:	Prepared for limma. Samples: 20, Proteins: 2831.
# 20-Jul-24 23:23:43 - root - INFO - SERVER: Number of proteins: 2831, number of variables: 6
# 20-Jul-24 23:23:43 - root - INFO - SMPC is not used, aggregating masks
# 20-Jul-24 23:23:44 - root - INFO - Client lab_A:	Collinearity check and update completed.
# 20-Jul-24 23:23:44 - root - INFO - Client lab_A:	Collinearity check completed.
# 20-Jul-24 23:23:44 - root - INFO - Client lab_B:	Collinearity check completed.
# 20-Jul-24 23:23:44 - root - INFO - Client lab_C:	Collinearity check completed.
# 20-Jul-24 23:23:44 - root - INFO - Client lab_D:	Collinearity check completed.
# 20-Jul-24 23:23:44 - root - INFO - Client lab_E:	Collinearity check completed.
# 20-Jul-24 23:23:44 - root - INFO - Start computing XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - XtX and XtY have been computed for lab_A
# 20-Jul-24 23:23:44 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Jul-24 23:23:44 - root - INFO - Start computing XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - XtX and XtY have been computed for lab_B
# 20-Jul-24 23:23:44 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Jul-24 23:23:44 - root - INFO - Start computing XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - XtX and XtY have been computed for lab_C
# 20-Jul-24 23:23:44 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Jul-24 23:23:44 - root - INFO - Start computing XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - XtX and XtY have been computed for lab_D
# 20-Jul-24 23:23:44 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Jul-24 23:23:44 - root - INFO - Start computing XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - XtX and XtY have been computed for lab_E
# 20-Jul-24 23:23:44 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 20-Jul-24 23:23:44 - root - INFO - SMPC is not used, aggregating masks
# 20-Jul-24 23:23:44 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 20-Jul-24 23:23:44 - root - INFO - SERVER: XtX and XtY have been aggregated
# 20-Jul-24 23:23:44 - root - INFO - SERVER: Computing beta and stdev
# 20-Jul-24 23:23:44 - root - INFO - Detected partial NA coefficients for 559 probe(s).
# 20-Jul-24 23:23:44 - root - INFO - Start computation of SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - SSE and cov_coef have been computed for lab_A
# 20-Jul-24 23:23:44 - root - INFO - Start computation of SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - SSE and cov_coef have been computed for lab_B
# 20-Jul-24 23:23:44 - root - INFO - Start computation of SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - SSE and cov_coef have been computed for lab_C
# 20-Jul-24 23:23:44 - root - INFO - Start computation of SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - SSE and cov_coef have been computed for lab_D
# 20-Jul-24 23:23:44 - root - INFO - Start computation of SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - SSE and cov_coef have been computed for lab_E
# 20-Jul-24 23:23:44 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 20-Jul-24 23:23:44 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 20-Jul-24 23:23:44 - root - INFO - Making contrasts...
# 20-Jul-24 23:23:44 - root - INFO - Fit contrasts...
# 20-Jul-24 23:23:44 - root - INFO - .... orthogonality of design matrix is False
# 20-Jul-24 23:23:44 - root - INFO - Start eBays stage...
# 20-Jul-24 23:23:44 - root - INFO - "Result table is pre-computed...
# 20-Jul-24 23:23:44 - root - INFO - Computing B statistic...
# 20-Jul-24 23:23:45 - root - INFO - Calculating tail p-values
# 20-Jul-24 23:23:45 - root - INFO - B statistic has been computed...
# 20-Jul-24 23:23:45 - root - INFO - Computing p-values...
# 20-Jul-24 23:23:45 - root - INFO - P-values have been computed...
# 20-Jul-24 23:23:45 - root - INFO - Size of global min counts: (2831,)
# 20-Jul-24 23:23:45 - root - INFO - Start spectral count eBayes stage...
# 20-Jul-24 23:23:45 - root - INFO - Fitting LOWESS curve...
# 20-Jul-24 23:23:45 - root - INFO - min_count: (2831,), log_var: (2831,)
# 20-Jul-24 23:23:46 - root - INFO - Spectral count eBayes stage is done...
# 20-Jul-24 23:23:46 - root - INFO - Writing results...
# 20-Jul-24 23:23:46 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial//balanced/results/DPE.csv
