# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/
# Out:
# 15-May-24 13:32:04 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 15-May-24 13:32:04 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 15-May-24 13:32:04 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/fedprot/lib/R
# 15-May-24 13:32:04 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/fedprot/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 15-May-24 13:32:04 - rpy2.situation - INFO - R library path:
# 15-May-24 13:32:04 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 15-May-24 13:32:04 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 15-May-24 13:32:04 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 15-Mai-24 13:32:04 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 15-Mai-24 13:32:04 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//balanced
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A: Using counts.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A: 24 samples are kept.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A: Loaded 24 samples and 2548 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B: Using counts.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B: 23 samples are kept.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B: Loaded 23 samples and 2846 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C: Using counts.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C: 23 samples are kept.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C: Loaded 23 samples and 2819 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D: Using counts.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D: 24 samples are kept.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D: Loaded 24 samples and 2813 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E: Using counts.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E: 24 samples are kept.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 15-Mai-24 13:32:04 - root - INFO - SERVER: Common proteins: 2273
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Protein groups are validated.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Validated 24 samples and 2273 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_A data: 24
# 15-Mai-24 13:32:04 - root - INFO - Protein groups in lab_A data:  2273
# 15-Mai-24 13:32:04 - root - INFO - Design lab_A has beed updated with cohort effects
# 15-Mai-24 13:32:04 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Protein groups are validated.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Validated 23 samples and 2273 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_B data: 23
# 15-Mai-24 13:32:04 - root - INFO - Protein groups in lab_B data:  2273
# 15-Mai-24 13:32:04 - root - INFO - Design lab_B has beed updated with cohort effects
# 15-Mai-24 13:32:04 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Protein groups are validated.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Validated 23 samples and 2273 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_C data: 23
# 15-Mai-24 13:32:04 - root - INFO - Protein groups in lab_C data:  2273
# 15-Mai-24 13:32:04 - root - INFO - Design lab_C has beed updated with cohort effects
# 15-Mai-24 13:32:04 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Protein groups are validated.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Validated 24 samples and 2273 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_D data: 24
# 15-Mai-24 13:32:04 - root - INFO - Protein groups in lab_D data:  2273
# 15-Mai-24 13:32:04 - root - INFO - Design lab_D has beed updated with cohort effects
# 15-Mai-24 13:32:04 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Protein groups are validated.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'file', 'lab'}
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Validated 24 samples and 2273 proteins.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_E data: 24
# 15-Mai-24 13:32:04 - root - INFO - Protein groups in lab_E data:  2273
# 15-Mai-24 13:32:04 - root - INFO - Design lab_E has beed updated with cohort effects
# 15-Mai-24 13:32:04 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:04 - root - INFO - SERVER: Proteins after filtering: 2272
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_A data: 24, protein groups: 2272
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_B data: 23, protein groups: 2272
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_C data: 23, protein groups: 2272
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_D data: 24, protein groups: 2272
# 15-Mai-24 13:32:04 - root - INFO - Samples in lab_E data: 24, protein groups: 2272
# 15-Mai-24 13:32:04 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - XtX and XtY have been computed for lab_A
# 15-Mai-24 13:32:04 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:04 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - XtX and XtY have been computed for lab_B
# 15-Mai-24 13:32:04 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:04 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - XtX and XtY have been computed for lab_C
# 15-Mai-24 13:32:04 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:04 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - XtX and XtY have been computed for lab_D
# 15-Mai-24 13:32:04 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:04 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - XtX and XtY have been computed for lab_E
# 15-Mai-24 13:32:04 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:04 - root - INFO - SERVER: Number of proteins: 2272, number of variables: 6
# 15-Mai-24 13:32:04 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 15-Mai-24 13:32:04 - root - INFO - SERVER: XtX and XtY have been aggregated
# 15-Mai-24 13:32:04 - root - INFO - SERVER: Computing beta and stdev
# 15-Mai-24 13:32:04 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - SSE and cov_coef have been computed for lab_A
# 15-Mai-24 13:32:05 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - SSE and cov_coef have been computed for lab_B
# 15-Mai-24 13:32:05 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - SSE and cov_coef have been computed for lab_C
# 15-Mai-24 13:32:05 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - SSE and cov_coef have been computed for lab_D
# 15-Mai-24 13:32:05 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - SSE and cov_coef have been computed for lab_E
# 15-Mai-24 13:32:05 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 15-Mai-24 13:32:05 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 15-Mai-24 13:32:05 - root - INFO - Making contrasts...
# 15-Mai-24 13:32:05 - root - INFO - Fit contrasts...
# 15-Mai-24 13:32:05 - root - INFO - .... orthogonality of design matrix is False
# 15-Mai-24 13:32:05 - root - INFO - Start eBays stage...
# 15-Mai-24 13:32:05 - root - INFO - "Result table is pre-computed...
# 15-Mai-24 13:32:05 - root - INFO - Computing B statistic...
# 15-Mai-24 13:32:05 - root - INFO - Calculating tail p-values
# 15-Mai-24 13:32:05 - root - INFO - B statistic has been computed...
# 15-Mai-24 13:32:05 - root - INFO - Computing p-values...
# 15-Mai-24 13:32:05 - root - INFO - P-values have been computed...
# 15-Mai-24 13:32:05 - root - INFO - Min counts have been computed...
# 15-Mai-24 13:32:05 - root - INFO - Min counts have been aggregated...
# 15-Mai-24 13:32:05 - root - INFO - Size of global min counts: (2272,)
# 15-Mai-24 13:32:05 - root - INFO - Start spectral count eBayes stage...
# 15-Mai-24 13:32:05 - root - INFO - Fitting LOWESS curve...
# 15-Mai-24 13:32:05 - root - INFO - min_count: (2272,), log_var: (2272,)
# 15-Mai-24 13:32:06 - root - INFO - Spectral count eBayes stage is done...
# 15-Mai-24 13:32:06 - root - INFO - Writing results...
# 15-Mai-24 13:32:06 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial//balanced/results/DPE.csv

# %% [markdown]
# # Imbalanced

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ imbalanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial
# Out:
# 15-May-24 13:32:10 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 15-May-24 13:32:10 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 15-May-24 13:32:10 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/fedprot/lib/R
# 15-May-24 13:32:10 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/fedprot/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 15-May-24 13:32:11 - rpy2.situation - INFO - R library path:
# 15-May-24 13:32:11 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 15-May-24 13:32:11 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 15-May-24 13:32:11 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 15-Mai-24 13:32:11 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 15-Mai-24 13:32:11 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data//imbalanced
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A: Using counts.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A: Samples are filtered based on target classes.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A: 15 samples are kept.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A: Loaded 15 samples and 2548 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B: Using counts.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B: Samples are filtered based on target classes.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B: 13 samples are kept.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B: Loaded 13 samples and 2844 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C: Using counts.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C: Samples are filtered based on target classes.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C: 14 samples are kept.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C: Loaded 14 samples and 2811 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D: Using counts.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D: Samples are filtered based on target classes.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D: 15 samples are kept.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D: Loaded 15 samples and 2813 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E: Using counts.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E: Samples are filtered based on target classes.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E: 24 samples are kept.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 15-Mai-24 13:32:11 - root - INFO - SERVER: Common proteins: 2272
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Protein groups are validated.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Validated 15 samples and 2272 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Adding cohort as a covariate.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_A data: 15
# 15-Mai-24 13:32:11 - root - INFO - Protein groups in lab_A data:  2272
# 15-Mai-24 13:32:11 - root - INFO - Design lab_A has beed updated with cohort effects
# 15-Mai-24 13:32:11 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Protein groups are validated.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Validated 13 samples and 2272 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Adding cohort as a covariate.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_B data: 13
# 15-Mai-24 13:32:11 - root - INFO - Protein groups in lab_B data:  2272
# 15-Mai-24 13:32:11 - root - INFO - Design lab_B has beed updated with cohort effects
# 15-Mai-24 13:32:11 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Protein groups are validated.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Validated 14 samples and 2272 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Adding cohort as a covariate.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_C data: 14
# 15-Mai-24 13:32:11 - root - INFO - Protein groups in lab_C data:  2272
# 15-Mai-24 13:32:11 - root - INFO - Design lab_C has beed updated with cohort effects
# 15-Mai-24 13:32:11 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Protein groups are validated.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Validated 15 samples and 2272 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Adding cohort as a covariate.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_D data: 15
# 15-Mai-24 13:32:11 - root - INFO - Protein groups in lab_D data:  2272
# 15-Mai-24 13:32:11 - root - INFO - Design lab_D has beed updated with cohort effects
# 15-Mai-24 13:32:11 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Protein groups are validated.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix: {'lab', 'file'}
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Validated 24 samples and 2272 proteins.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Adding cohort effects to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Adding cohort as a covariate.
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Cohort effects are added to the design matrix.
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_E data: 24
# 15-Mai-24 13:32:11 - root - INFO - Protein groups in lab_E data:  2272
# 15-Mai-24 13:32:11 - root - INFO - Design lab_E has beed updated with cohort effects
# 15-Mai-24 13:32:11 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded.
# 15-Mai-24 13:32:11 - root - INFO - SERVER: Proteins after filtering: 2271
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_A data: 15, protein groups: 2271
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_B data: 13, protein groups: 2271
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_C data: 14, protein groups: 2271
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_D data: 15, protein groups: 2271
# 15-Mai-24 13:32:11 - root - INFO - Samples in lab_E data: 24, protein groups: 2271
# 15-Mai-24 13:32:11 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - XtX and XtY have been computed for lab_A
# 15-Mai-24 13:32:11 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:11 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - XtX and XtY have been computed for lab_B
# 15-Mai-24 13:32:11 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:11 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - XtX and XtY have been computed for lab_C
# 15-Mai-24 13:32:11 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:11 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - XtX and XtY have been computed for lab_D
# 15-Mai-24 13:32:11 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:11 - root - INFO - Start computing XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - XtX and XtY have been computed for lab_E
# 15-Mai-24 13:32:11 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 15-Mai-24 13:32:11 - root - INFO - SERVER: Number of proteins: 2271, number of variables: 6
# 15-Mai-24 13:32:11 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 15-Mai-24 13:32:11 - root - INFO - SERVER: XtX and XtY have been aggregated
# 15-Mai-24 13:32:11 - root - INFO - SERVER: Computing beta and stdev
# 15-Mai-24 13:32:11 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - SSE and cov_coef have been computed for lab_A
# 15-Mai-24 13:32:11 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - SSE and cov_coef have been computed for lab_B
# 15-Mai-24 13:32:11 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - SSE and cov_coef have been computed for lab_C
# 15-Mai-24 13:32:11 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - SSE and cov_coef have been computed for lab_D
# 15-Mai-24 13:32:11 - root - INFO - Start computation of SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - SSE and cov_coef have been computed for lab_E
# 15-Mai-24 13:32:11 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 15-Mai-24 13:32:11 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 15-Mai-24 13:32:11 - root - INFO - Making contrasts...
# 15-Mai-24 13:32:11 - root - INFO - Fit contrasts...
# 15-Mai-24 13:32:11 - root - INFO - .... orthogonality of design matrix is False
# 15-Mai-24 13:32:11 - root - INFO - Start eBays stage...
# 15-Mai-24 13:32:11 - root - INFO - "Result table is pre-computed...
# 15-Mai-24 13:32:11 - root - INFO - Computing B statistic...
# 15-Mai-24 13:32:12 - root - INFO - Calculating tail p-values
# 15-Mai-24 13:32:12 - root - INFO - B statistic has been computed...
# 15-Mai-24 13:32:12 - root - INFO - Computing p-values...
# 15-Mai-24 13:32:12 - root - INFO - P-values have been computed...
# 15-Mai-24 13:32:12 - root - INFO - Min counts have been computed...
# 15-Mai-24 13:32:12 - root - INFO - Min counts have been aggregated...
# 15-Mai-24 13:32:12 - root - INFO - Size of global min counts: (2271,)
# 15-Mai-24 13:32:12 - root - INFO - Start spectral count eBayes stage...
# 15-Mai-24 13:32:12 - root - INFO - Fitting LOWESS curve...
# 15-Mai-24 13:32:12 - root - INFO - min_count: (2271,), log_var: (2271,)
# 15-Mai-24 13:32:13 - root - INFO - Spectral count eBayes stage is done...
# 15-Mai-24 13:32:13 - root - INFO - Writing results...
# 15-Mai-24 13:32:13 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/imbalanced/results/DPE.csv
