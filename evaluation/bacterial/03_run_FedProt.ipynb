# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/bacterial_data/"
# MODE = "balanced"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ balanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/
# Out:
# 10-May-24 15:39:28 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 10-May-24 15:39:28 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 10-May-24 15:39:28 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/fedprot/lib/R
# 10-May-24 15:39:28 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/fedprot/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 10-May-24 15:39:29 - rpy2.situation - INFO - R library path:
# 10-May-24 15:39:29 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 10-May-24 15:39:29 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 10-May-24 15:39:29 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 10-Mai-24 15:39:29 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A: Using counts.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A: Loaded 24 samples and 2548 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B: Using counts.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B: Loaded 23 samples and 2846 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C: Using counts.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C: Loaded 23 samples and 2819 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D: Using counts.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D: Loaded 24 samples and 2813 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E: Using counts.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 10-Mai-24 15:39:29 - root - INFO - SERVER: Common proteins: 2273
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A: Validated 24 samples and 2273 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_A data: 24
# 10-Mai-24 15:39:29 - root - INFO - Protein groups in lab_A data:  2273
# 10-Mai-24 15:39:29 - root - INFO - Design lab_A has beed updated with cohort effects
# 10-Mai-24 15:39:29 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B: Validated 23 samples and 2273 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_B data: 23
# 10-Mai-24 15:39:29 - root - INFO - Protein groups in lab_B data:  2273
# 10-Mai-24 15:39:29 - root - INFO - Design lab_B has beed updated with cohort effects
# 10-Mai-24 15:39:29 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C: Validated 23 samples and 2273 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_C data: 23
# 10-Mai-24 15:39:29 - root - INFO - Protein groups in lab_C data:  2273
# 10-Mai-24 15:39:29 - root - INFO - Design lab_C has beed updated with cohort effects
# 10-Mai-24 15:39:29 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D: Validated 24 samples and 2273 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_D data: 24
# 10-Mai-24 15:39:29 - root - INFO - Protein groups in lab_D data:  2273
# 10-Mai-24 15:39:29 - root - INFO - Design lab_D has beed updated with cohort effects
# 10-Mai-24 15:39:29 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix:
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E: Validated 24 samples and 2273 proteins.
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_E data: 24
# 10-Mai-24 15:39:29 - root - INFO - Protein groups in lab_E data:  2273
# 10-Mai-24 15:39:29 - root - INFO - Design lab_E has beed updated with cohort effects
# 10-Mai-24 15:39:29 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 15:39:29 - root - INFO - SERVER: Proteins after filtering: 2272
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_A data: 24, protein groups: 2272
# 10-Mai-24 15:39:29 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - XtX and XtY have been computed for lab_A
# 10-Mai-24 15:39:29 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_B data: 23, protein groups: 2272
# 10-Mai-24 15:39:29 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - XtX and XtY have been computed for lab_B
# 10-Mai-24 15:39:29 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_C data: 23, protein groups: 2272
# 10-Mai-24 15:39:29 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - XtX and XtY have been computed for lab_C
# 10-Mai-24 15:39:29 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_D data: 24, protein groups: 2272
# 10-Mai-24 15:39:29 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - XtX and XtY have been computed for lab_D
# 10-Mai-24 15:39:29 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 15:39:29 - root - INFO - Samples in lab_E data: 24, protein groups: 2272
# 10-Mai-24 15:39:29 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - XtX and XtY have been computed for lab_E
# 10-Mai-24 15:39:29 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 15:39:29 - root - INFO - SERVER: Number of proteins: 2272, number of variables: 6
# 10-Mai-24 15:39:29 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 10-Mai-24 15:39:29 - root - INFO - SERVER: XtX and XtY have been aggregated
# 10-Mai-24 15:39:29 - root - INFO - SERVER: Computing beta and stdev
# 10-Mai-24 15:39:29 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - SSE and cov_coef have been computed for lab_A
# 10-Mai-24 15:39:29 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - SSE and cov_coef have been computed for lab_B
# 10-Mai-24 15:39:29 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - SSE and cov_coef have been computed for lab_C
# 10-Mai-24 15:39:29 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - SSE and cov_coef have been computed for lab_D
# 10-Mai-24 15:39:29 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - SSE and cov_coef have been computed for lab_E
# 10-Mai-24 15:39:29 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 10-Mai-24 15:39:29 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 10-Mai-24 15:39:29 - root - INFO - Making contrasts...
# 10-Mai-24 15:39:29 - root - INFO - Fit contrasts...
# 10-Mai-24 15:39:29 - root - INFO - .... orthogonality of design matrix is False
# 10-Mai-24 15:39:29 - root - INFO - Start eBays stage...
# 10-Mai-24 15:39:29 - root - INFO - "Result table is pre-computed...
# 10-Mai-24 15:39:29 - root - INFO - Computing B statistic...
# 10-Mai-24 15:39:30 - root - INFO - Calculating tail p-values
# 10-Mai-24 15:39:30 - root - INFO - B statistic has been computed...
# 10-Mai-24 15:39:30 - root - INFO - Computing p-values...
# 10-Mai-24 15:39:30 - root - INFO - P-values have been computed...
# 10-Mai-24 15:39:30 - root - INFO - Min counts have been computed...
# 10-Mai-24 15:39:30 - root - INFO - Min counts have been aggregated...
# 10-Mai-24 15:39:30 - root - INFO - Size of global min counts: (2272,)
# 10-Mai-24 15:39:30 - root - INFO - Start spectral count eBayes stage...
# 10-Mai-24 15:39:30 - root - INFO - Fitting LOWESS curve...
# 10-Mai-24 15:39:30 - root - INFO - min_count: (2272,), log_var: (2272,)
# 10-Mai-24 15:39:31 - root - INFO - Spectral count eBayes stage is done...
# 10-Mai-24 15:39:31 - root - INFO - Writing results...
# 10-Mai-24 15:39:31 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial//balanced/results/DPE.csv

# %% [markdown]
# # Imbalanced

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data/bacterial_data/ imbalanced lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial
# Out:
# 10-May-24 17:05:35 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 10-May-24 17:05:36 - rpy2.situation - DEBUG - Looking for R home with: R RHOME
# 10-May-24 17:05:36 - rpy2.situation - INFO - R home found: /home/yuliya/anaconda3/envs/fedprot/lib/R
# 10-May-24 17:05:36 - rpy2.situation - DEBUG - Looking for LD_LIBRARY_PATH with: /home/yuliya/anaconda3/envs/fedprot/lib/R/bin/Rscript -e cat(Sys.getenv("LD_LIBRARY_PATH"))
# 10-May-24 17:05:36 - rpy2.situation - INFO - R library path:
# 10-May-24 17:05:36 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 10-May-24 17:05:36 - rpy2.rinterface_lib.ffi_proxy - DEBUG - cffi mode is InterfaceType.API
# 10-May-24 17:05:36 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 10-Mai-24 17:05:36 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A: Using counts.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A: Log2(x+1) transformed intensities.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A: Loaded 15 samples and 2548 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B: Using counts.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B: Log2(x+1) transformed intensities.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B: Loaded 13 samples and 2844 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C: Using counts.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C: Log2(x+1) transformed intensities.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C: Loaded 14 samples and 2811 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D: Using counts.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D: Log2(x+1) transformed intensities.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D: Loaded 15 samples and 2813 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E: Using counts.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E: Log2(x+1) transformed intensities.
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E: Loaded 24 samples and 2401 proteins.
# 10-Mai-24 17:05:36 - root - INFO - SERVER: Common proteins: 2272
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A:	2 columns are excluded from the design matrix:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A: Validated 15 samples and 2272 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Samples in lab_A data: 15
# 10-Mai-24 17:05:36 - root - INFO - Protein groups in lab_A data:  2272
# 10-Mai-24 17:05:36 - root - INFO - Design lab_A has beed updated with cohort effects
# 10-Mai-24 17:05:36 - root - INFO - Client lab_A:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B:	2 columns are excluded from the design matrix:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B: Validated 13 samples and 2272 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Samples in lab_B data: 13
# 10-Mai-24 17:05:36 - root - INFO - Protein groups in lab_B data:  2272
# 10-Mai-24 17:05:36 - root - INFO - Design lab_B has beed updated with cohort effects
# 10-Mai-24 17:05:36 - root - INFO - Client lab_B:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C:	2 columns are excluded from the design matrix:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C: Validated 14 samples and 2272 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Samples in lab_C data: 14
# 10-Mai-24 17:05:36 - root - INFO - Protein groups in lab_C data:  2272
# 10-Mai-24 17:05:36 - root - INFO - Design lab_C has beed updated with cohort effects
# 10-Mai-24 17:05:36 - root - INFO - Client lab_C:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D:	2 columns are excluded from the design matrix:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D: Validated 15 samples and 2272 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Samples in lab_D data: 15
# 10-Mai-24 17:05:36 - root - INFO - Protein groups in lab_D data:  2272
# 10-Mai-24 17:05:36 - root - INFO - Design lab_D has beed updated with cohort effects
# 10-Mai-24 17:05:36 - root - INFO - Client lab_D:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E:	2 columns are excluded from the design matrix:
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E: Validated 24 samples and 2272 proteins.
# 10-Mai-24 17:05:36 - root - INFO - Samples in lab_E data: 24
# 10-Mai-24 17:05:36 - root - INFO - Protein groups in lab_E data:  2272
# 10-Mai-24 17:05:36 - root - INFO - Design lab_E has beed updated with cohort effects
# 10-Mai-24 17:05:36 - root - INFO - Client lab_E:	Protein groups detected in less than 0.8 of each target class will be excluded:
# 10-Mai-24 17:05:37 - root - INFO - SERVER: Proteins after filtering: 2271
# 10-Mai-24 17:05:37 - root - INFO - Samples in lab_A data: 15, protein groups: 2271
# 10-Mai-24 17:05:37 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - XtX and XtY have been computed for lab_A
# 10-Mai-24 17:05:37 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 17:05:37 - root - INFO - Samples in lab_B data: 13, protein groups: 2271
# 10-Mai-24 17:05:37 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - XtX and XtY have been computed for lab_B
# 10-Mai-24 17:05:37 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 17:05:37 - root - INFO - Samples in lab_C data: 14, protein groups: 2271
# 10-Mai-24 17:05:37 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - XtX and XtY have been computed for lab_C
# 10-Mai-24 17:05:37 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 17:05:37 - root - INFO - Samples in lab_D data: 15, protein groups: 2271
# 10-Mai-24 17:05:37 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - XtX and XtY have been computed for lab_D
# 10-Mai-24 17:05:37 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 17:05:37 - root - INFO - Samples in lab_E data: 24, protein groups: 2271
# 10-Mai-24 17:05:37 - root - INFO - Start computing XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - XtX and XtY have been computed for lab_E
# 10-Mai-24 17:05:37 - root - INFO - Design colnames: ['Glu' 'Pyr' 'lab_B' 'lab_C' 'lab_D' 'lab_E']
# 10-Mai-24 17:05:37 - root - INFO - SERVER: Number of proteins: 2271, number of variables: 6
# 10-Mai-24 17:05:37 - root - INFO - SMPC is not used, aggregating XtX and XtY
# 10-Mai-24 17:05:37 - root - INFO - SERVER: XtX and XtY have been aggregated
# 10-Mai-24 17:05:37 - root - INFO - SERVER: Computing beta and stdev
# 10-Mai-24 17:05:37 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - SSE and cov_coef have been computed for lab_A
# 10-Mai-24 17:05:37 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - SSE and cov_coef have been computed for lab_B
# 10-Mai-24 17:05:37 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - SSE and cov_coef have been computed for lab_C
# 10-Mai-24 17:05:37 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - SSE and cov_coef have been computed for lab_D
# 10-Mai-24 17:05:37 - root - INFO - Start computation of SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - SSE and cov_coef have been computed for lab_E
# 10-Mai-24 17:05:37 - root - INFO - SERVER: Aggregating SSE and cov_coef...
# 10-Mai-24 17:05:37 - root - INFO - Aggregation of SSE is done, start computing global parameters...
# 10-Mai-24 17:05:37 - root - INFO - Making contrasts...
# 10-Mai-24 17:05:37 - root - INFO - Fit contrasts...
# 10-Mai-24 17:05:37 - root - INFO - .... orthogonality of design matrix is False
# 10-Mai-24 17:05:37 - root - INFO - Start eBays stage...
# 10-Mai-24 17:05:37 - root - INFO - "Result table is pre-computed...
# 10-Mai-24 17:05:37 - root - INFO - Computing B statistic...
# 10-Mai-24 17:05:38 - root - INFO - Calculating tail p-values
# 10-Mai-24 17:05:38 - root - INFO - B statistic has been computed...
# 10-Mai-24 17:05:38 - root - INFO - Computing p-values...
# 10-Mai-24 17:05:38 - root - INFO - P-values have been computed...
# 10-Mai-24 17:05:38 - root - INFO - Min counts have been computed...
# 10-Mai-24 17:05:38 - root - INFO - Min counts have been aggregated...
# 10-Mai-24 17:05:38 - root - INFO - Size of global min counts: (2271,)
# 10-Mai-24 17:05:38 - root - INFO - Start spectral count eBayes stage...
# 10-Mai-24 17:05:38 - root - INFO - Fitting LOWESS curve...
# 10-Mai-24 17:05:38 - root - INFO - min_count: (2271,), log_var: (2271,)
# 10-Mai-24 17:05:39 - root - INFO - Spectral count eBayes stage is done...
# 10-Mai-24 17:05:39 - root - INFO - Writing results...
# 10-Mai-24 17:05:39 - root - INFO - Results have been saved to /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial/imbalanced/results/DPE.csv
