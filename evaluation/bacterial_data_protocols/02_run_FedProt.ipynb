# %% [markdown]
# # Run for balanced
#
# Run
# /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py
# with args:
#
# data_dir = "/home/yuliya/repos/cosybio/FedProt/data/"
# MODE = "bacterial_data_protocols"
# cohorts = ["lab_A", "lab_B", "lab_C", "lab_D", "lab_E"]
# output_path = "/home/yuliya/repos/cosybio/FedProt/evaluation/bacterial_data_protocols/"

# %%
# %%bash
# python /home/yuliya/repos/cosybio/FedProt/evaluation_utils/fedprot_prototype/fedprot_script.py /home/yuliya/repos/cosybio/FedProt/data bacterial_data_protocols lab_A,lab_B,lab_C,lab_D,lab_E /home/yuliya/repos/cosybio/FedProt/evaluation/ /home/yuliya/repos/cosybio/FedProt/evaluation/bacterial_data_protocols/analysed_proteins.json
# Out:
# 20-Feb-25 20:09:27 - rpy2.situation - INFO - cffi mode is CFFI_MODE.ANY
# 20-Feb-25 20:09:27 - rpy2.situation - INFO - R home found: /home/yuliya/miniforge3/envs/FedProt/lib/R
# 20-Feb-25 20:09:27 - rpy2.situation - INFO - R library path:
# 20-Feb-25 20:09:27 - rpy2.situation - INFO - LD_LIBRARY_PATH:
# 20-Feb-25 20:09:27 - rpy2.rinterface_lib.embedded - INFO - Default options to initialize R: rpy2, --quiet, --no-save
# 20-Feb-25 20:09:27 - rpy2.rinterface_lib.embedded - INFO - R is already initialized. No need to initialize.
# 20-Feb-25 20:09:27 - root - INFO - Number of arguments: 6
# 20-Feb-25 20:09:27 - root - INFO - Data directory: /home/yuliya/repos/cosybio/FedProt/data/bacterial_data_protocols
# 20-Feb-25 20:09:27 - root - INFO - Client lab_A: Using counts.
# 20-Feb-25 20:09:27 - root - INFO - Client lab_A: Replacing rows with only one non-NA value with NA.
# 20-Feb-25 20:09:27 - root - INFO - Client lab_A: Rows will be affected : 0
# ...
