# %%
library(tidyverse)
library(cowplot)
library(VennDiagram)
library(gridExtra)
library(UpSetR)

# %% [markdown]
# # Read files

# %%
pgnames_mxout <- function(path){
    PG_report <- read.table(
        path,
        header=T,
        sep="\t",
        stringsAsFactors = F)
    
    # remove decoy matches and matches to contaminant
    # PG_report <- PG_report[!PG_report$Reverse=="+",]
    # PG_report <- PG_report[!PG_report$Potential.contaminant=="+",]
    # # if the PG_report$Only.identified.by.site is not all NA and contains "+" values - remove this rows
    # if(!all(is.na(PG_report$Only.identified.by.site))) {
    #     # # Only.identified.by.site - exclude proteins that were only identified by a modification site
    #     PG_report <- PG_report[!PG_report$Only.identified.by.site=="+",]
    # }

    # PG_report <- PG_report[PG_report$Gene.names != '',]


    df_names <- PG_report %>%
        select(Protein.IDs, Majority.protein.IDs, Gene.names, Peptide.IDs, Peptide.is.razor, Peptide.sequences)

    return(df_names)    
}

# %%
list_of_outputs <- list(
    "Center1" = "/home/yuliya/repos/cosybio/FedProt/data/TMT_data/raw_MaxQuant_reports/proteinGroups_center1.txt",
    "Center2" = "/home/yuliya/repos/cosybio/FedProt/data/TMT_data/raw_MaxQuant_reports/proteinGroups_center2.txt",
    "Center3" = "/home/yuliya/repos/cosybio/FedProt/data/TMT_data/raw_MaxQuant_reports/proteinGroups_center3.txt"
)

combined_pg_intensities <- list()

for(center in names(list_of_outputs)) {
    center_folder <- ifelse(center == "Center1", "center_one", ifelse(center == "Center2", "center_two", "center_three"))
    pg_intensities <- pgnames_mxout(list_of_outputs[[center]])
    # add it to the list using the center name as the key
    combined_pg_intensities <- c(combined_pg_intensities, list(pg_intensities))
    
}
# add names to the list
names(combined_pg_intensities) <- names(list_of_outputs)
# head(combined_pg_intensities)
colnames(combined_pg_intensities[[1]])
# Out:
# [1] "Protein.IDs"          "Majority.protein.IDs" "Gene.names"
# [4] "Peptide.IDs"          "Peptide.is.razor"     "Peptide.sequences"

# %%
# intersect the protein names from all centers
intersect(
    combined_pg_intensities[["Center1"]]$Majority.protein.IDs,
    combined_pg_intensities[["Center3"]]$Majority.protein.IDs
) %>% length()

intersect(
    combined_pg_intensities[["Center1"]]$Majority.protein.IDs,
    combined_pg_intensities[["Center2"]]$Majority.protein.IDs
) %>% length()


intersect(
    combined_pg_intensities[["Center2"]]$Majority.protein.IDs,
    combined_pg_intensities[["Center3"]]$Majority.protein.IDs
) %>% length()

# intersect the gene names from all centers
intersect(
    combined_pg_intensities[["Center1"]]$Majority.protein.IDs,
    combined_pg_intensities[["Center3"]]$Majority.protein.IDs
) %>% intersect(combined_pg_intensities[["Center2"]]$Majority.protein.IDs) %>% length()
# Out:
# [1] 308
# [1] 316
# [1] 317
# [1] 264

# %%
# same for gene names
intersect(
    combined_pg_intensities[["Center1"]]$Gene.names,
    combined_pg_intensities[["Center3"]]$Gene.names
) %>% intersect(combined_pg_intensities[["Center2"]]$Gene.names) %>% length()
# Out:
# [1] 354

# %%
# same for gene names
intersect(
    combined_pg_intensities[["Center1"]]$Peptide.sequences,
    combined_pg_intensities[["Center3"]]$Peptide.sequences
) %>% intersect(combined_pg_intensities[["Center2"]]$Peptide.sequences) %>% length()
# Out:
# [1] 17

# %% [markdown]
# ## Peptide.sequences

# %%
pg_one <- unique(unlist(strsplit(combined_pg_intensities[["Center1"]]$Peptide.sequences, ";")))
length(pg_one)

pg_two <- unique(unlist(strsplit(combined_pg_intensities[["Center2"]]$Peptide.sequences, ";")))
length(pg_two)

pg_three <- unique(unlist(strsplit(combined_pg_intensities[["Center3"]]$Peptide.sequences, ";")))
length(pg_three)

common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three)
# Out:
# [1] 5955
# [1] 6300
# [1] 5526

# %%
# intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# # plot venn  diagram
# grid.newpage()

# venn_plot <- venn.diagram(
#     x = list(
#         "Center1" = pg_one,
#         "Center2" = pg_two,
#         "Center3" = pg_three
#     ),
#     lwd = 2,
#     filename = NULL)

# grid.draw(venn_plot)
# Out:
# [1] 3913
# plot without title

# %%
all_elements <- unique(c(pg_one, pg_two, pg_three))

data <- data.frame(element = all_elements,
                   pg_one = as.integer(all_elements %in% pg_one),
                   pg_two = as.integer(all_elements %in% pg_two),
                   pg_three = as.integer(all_elements %in% pg_three))

options(repr.plot.width=6, repr.plot.height=3)
upset(data, sets = c("pg_one", "pg_two", "pg_three"), order.by = "freq",
        # add title to the whole plot

        main.bar.color = "black",
        sets.bar.color = "black",
        sets.x.label = "Number of peptides",
        )
# Out:
# plot without title

# %% [markdown]
# ## PG.IDs

# %%
pg_one <- unique(unlist(strsplit(combined_pg_intensities[["Center1"]]$Protein.IDs, ";")))
length(pg_one)

pg_two <- unique(unlist(strsplit(combined_pg_intensities[["Center2"]]$Protein.IDs, ";")))
length(pg_two)

pg_three <- unique(unlist(strsplit(combined_pg_intensities[["Center3"]]$Protein.IDs, ";")))
length(pg_three)

common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three)
# Out:
# [1] 2182
# [1] 2282
# [1] 1854

# %%
intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = pg_one,
        "Center2" = pg_two,
        "Center3" = pg_three
    ),
    lwd = 2,
    filename = NULL)

grid.draw(venn_plot)
# Out:
# [1] 1547
# plot without title

# %%
all_elements <- unique(c(pg_one, pg_two, pg_three))

data <- data.frame(element = all_elements,
                   pg_one = as.integer(all_elements %in% pg_one),
                   pg_two = as.integer(all_elements %in% pg_two),
                   pg_three = as.integer(all_elements %in% pg_three))

options(repr.plot.width=6, repr.plot.height=5)
upset(data, sets = c("pg_one", "pg_two", "pg_three"), order.by = "freq",
        # add title to the whole plot

        main.bar.color = "black",
        sets.bar.color = "black",
        sets.x.label = "Number of protein IDs",
        )
# Out:
# plot without title

# %%
# for each df in combined_pg_intensities, calculate the new column
# that contains the number of proteins in the intersection devided by the total number of proteins in the PG for each row

for(center in names(combined_pg_intensities)) {
    pg <- combined_pg_intensities[[center]]
    pg$Protein.IDs <- as.character(pg$Protein.IDs)
    pg$Protein.IDs <- strsplit(pg$Protein.IDs, ";")
    pg$Protein.IDs.common  <- sapply(pg$Protein.IDs, function(x) length(intersect(x, common_proteins))/length(x))
    combined_pg_intensities[[center]] <- pg
}

# %%
# print lenght of the Protein.IDs.common where value is equal 0
combined_pg_intensities[["Center1"]] %>% filter(Protein.IDs.common == 0) %>% nrow()
combined_pg_intensities[["Center2"]] %>% filter(Protein.IDs.common == 0) %>% nrow()
combined_pg_intensities[["Center3"]] %>% filter(Protein.IDs.common == 0) %>% nrow()

# Make a % for it
combined_pg_intensities[["Center1"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center1"]])
combined_pg_intensities[["Center2"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center2"]])
combined_pg_intensities[["Center3"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center3"]])
# Out:
# [1] 88
# [1] 117
# [1] 53
# [1] 0.18107
# [1] 0.2267442
# [1] 0.1196388

# %%
# create three plots with distributions of the common proteins in each center

p1 <- ggplot(combined_pg_intensities[["Center1"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center1", x="Proportion of common proteins in PG", y="Number of PG") +
    theme_minimal()

p2 <- ggplot(combined_pg_intensities[["Center2"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center2", x="Proportion of common proteins in PG", y="Number of PG") +
    theme_minimal()

p3 <- ggplot(combined_pg_intensities[["Center3"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center3", x="Proportion of common proteins in PG", y="Number of PG") +
    theme_minimal()

plot_grid(p1, p2, p3, labels = "AUTO", cols = 1)
# Out:
# Warning message in plot_grid(p1, p2, p3, labels = "AUTO", cols = 1):
# “Argument 'cols' is deprecated. Use 'ncol' instead.”
# plot without title

# %%
# Calculate the percentages
percent_c1 <- combined_pg_intensities[["Center1"]] %>% 
  filter(Protein.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center1"]]) * 100

percent_c2 <- combined_pg_intensities[["Center2"]] %>% 
  filter(Protein.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center2"]]) * 100

percent_c3 <- combined_pg_intensities[["Center3"]] %>% 
  filter(Protein.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center3"]]) * 100

# Create plots with annotations for the 0% bars
p1 <- ggplot(combined_pg_intensities[["Center1"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center1", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c1, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center1"]], Protein.IDs.common == 0)) +
    theme_minimal()

p2 <- ggplot(combined_pg_intensities[["Center2"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center2", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c2, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center2"]], Protein.IDs.common == 0)) +
    theme_minimal()

p3 <- ggplot(combined_pg_intensities[["Center3"]], aes(x=Protein.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center3", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c3, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center3"]], Protein.IDs.common == 0)) +
    theme_minimal()

# Combine the plots
plot_grid(p1, p2, p3, labels = "AUTO", cols = 1)
# Out:
# Warning message in plot_grid(p1, p2, p3, labels = "AUTO", cols = 1):
# “Argument 'cols' is deprecated. Use 'ncol' instead.”
# plot without title

# %%
# print lenght of the Protein.IDs.common where value is equal 0
combined_pg_intensities[["Center1"]] %>% filter(Protein.IDs.common == 0) %>% nrow()
combined_pg_intensities[["Center2"]] %>% filter(Protein.IDs.common == 0) %>% nrow()
combined_pg_intensities[["Center3"]] %>% filter(Protein.IDs.common == 0) %>% nrow()

# Make a % for it
combined_pg_intensities[["Center1"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center1"]])
combined_pg_intensities[["Center2"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center2"]])
combined_pg_intensities[["Center3"]] %>% filter(Protein.IDs.common == 0) %>% nrow() / nrow(combined_pg_intensities[["Center3"]])
# Out:
# [1] 88
# [1] 117
# [1] 53
# [1] 0.18107
# [1] 0.2267442
# [1] 0.1196388

# %%
nrow(combined_pg_intensities[["Center1"]])
nrow(combined_pg_intensities[["Center1"]]) - combined_pg_intensities[["Center1"]] %>% filter(Protein.IDs.common == 0) %>% nrow()

nrow(combined_pg_intensities[["Center2"]])
nrow(combined_pg_intensities[["Center2"]]) - combined_pg_intensities[["Center2"]] %>% filter(Protein.IDs.common == 0) %>% nrow()

nrow(combined_pg_intensities[["Center3"]])
nrow(combined_pg_intensities[["Center3"]]) - combined_pg_intensities[["Center3"]] %>% filter(Protein.IDs.common == 0) %>% nrow()
# Out:
# [1] 486
# [1] 398
# [1] 516
# [1] 399
# [1] 443
# [1] 390

# %% [markdown]
# ## Gene.names

# %%
combined_pg_intensities[["Center1"]] %>%
    filter(Gene.names != '') %>%
    select(Gene.names) %>%
    unique() %>%
    nrow()



combined_pg_intensities[["Center2"]] %>%
    filter(Gene.names != '') %>%
    select(Gene.names) %>%
    unique() %>%
    nrow()


combined_pg_intensities[["Center3"]] %>%
    filter(Gene.names != '') %>%
    select(Gene.names) %>%
    unique() %>%
    nrow()
# Out:
# [1] 506
# [1] 525
# [1] 454

# %%
intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = unique(filter(combined_pg_intensities[["Center1"]], Gene.names != '')$Gene.names),
        "Center2" = unique(filter(combined_pg_intensities[["Center2"]], Gene.names != '')$Gene.names),
        "Center3" = unique(filter(combined_pg_intensities[["Center3"]], Gene.names != '')$Gene.names)
    ),
    lwd = 2,
    main = "Unique Gene.names",
    filename = NULL)

options(repr.plot.width=4, repr.plot.height=4)
grid.draw(venn_plot)
# Out:
# [1] 954
# plot without title

# %%
gene_one <- unique(filter(combined_pg_intensities[["Center1"]], Gene.names != '')$Gene.names)
gene_two <- unique(filter(combined_pg_intensities[["Center2"]], Gene.names != '')$Gene.names)
gene_three <- unique(filter(combined_pg_intensities[["Center3"]], Gene.names != '')$Gene.names)

all_elements <- unique(c(gene_one, pg_two, pg_three))

data <- data.frame(element = all_elements,
                   pg_one = as.integer(all_elements %in% gene_one),
                   pg_two = as.integer(all_elements %in% gene_two),
                   pg_three = as.integer(all_elements %in% gene_three))

options(repr.plot.width=6, repr.plot.height=3)
upset(data, sets = c("pg_one", "pg_two", "pg_three"), order.by = "freq",
        # add title to the whole plot

        main.bar.color = "black",
        sets.bar.color = "black",
        sets.x.label = "Number of Gene names",
        )
# Out:
# plot without title

# %%
gene_one <- unique(unlist(strsplit(filter(combined_pg_intensities[["Center1"]], Gene.names != '')$Gene.names, ";")))
gene_two <- unique(unlist(strsplit(filter(combined_pg_intensities[["Center2"]], Gene.names != '')$Gene.names, ";")))
gene_three <- unique(unlist(strsplit(filter(combined_pg_intensities[["Center3"]], Gene.names != '')$Gene.names, ";")))

all_elements <- unique(c(gene_one, pg_two, pg_three))

data <- data.frame(element = all_elements,
                   pg_one = as.integer(all_elements %in% gene_one),
                   pg_two = as.integer(all_elements %in% gene_two),
                   pg_three = as.integer(all_elements %in% gene_three))

options(repr.plot.width=6, repr.plot.height=3)
upset(data, sets = c("pg_one", "pg_two", "pg_three"), order.by = "freq",
        # add title to the whole plot

        main.bar.color = "black",
        sets.bar.color = "black",
        sets.x.label = "Number of Gene names",
        )
# Out:
# plot without title

# %% [markdown]
# ## Majority.PG.ID

# %%
intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = combined_pg_intensities[["Center1"]]$Majority.protein.IDs,
        "Center2" = combined_pg_intensities[["Center2"]]$Majority.protein.IDs,
        "Center3" = combined_pg_intensities[["Center3"]]$Majority.protein.IDs
    ),
    lwd = 2,
    main = "Majority.protein.IDs",
    filename = NULL)

options(repr.plot.width=4, repr.plot.height=4)
grid.draw(venn_plot)
# Out:
# [1] 954
# plot without title

# %%
pg_one <- unique(unlist(strsplit(combined_pg_intensities[["Center1"]]$Majority.protein.IDs, ";")))
length(pg_one)

pg_two <- unique(unlist(strsplit(combined_pg_intensities[["Center2"]]$Majority.protein.IDs, ";")))
length(pg_two)

pg_three <- unique(unlist(strsplit(combined_pg_intensities[["Center3"]]$Majority.protein.IDs, ";")))
length(pg_three)

common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three) 
length(common_proteins)


# pg_one <- unique(combined_pg_intensities[["Center1"]]$Majority.protein.IDs, ";")
# length(pg_one)

# pg_two <- unique(combined_pg_intensities[["Center2"]]$Majority.protein.IDs, ";")
# length(pg_two)

# pg_three <- unique(combined_pg_intensities[["Center3"]]$Majority.protein.IDs, ";")
# length(pg_three)

# common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three) 
# length(common_proteins)
# Out:
# [1] 1706
# [1] 1734
# [1] 1394
# [1] 1057

# %%
intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = pg_one,
        "Center2" = pg_two,
        "Center3" = pg_three
    ),
    lwd = 2,
    filename = NULL)

grid.draw(venn_plot)
# Out:
# [1] 973
# plot without title

# %%
all_elements <- unique(c(pg_one, pg_two, pg_three))

data <- data.frame(element = all_elements,
                   pg_one = as.integer(all_elements %in% pg_one),
                   pg_two = as.integer(all_elements %in% pg_two),
                   pg_three = as.integer(all_elements %in% pg_three))

options(repr.plot.width=6, repr.plot.height=3)
upset(data, sets = c("pg_one", "pg_two", "pg_three"), order.by = "freq",
        # add title to the whole plot

        main.bar.color = "black",
        sets.bar.color = "black",
        sets.x.label = "Number of Majority.protein.IDs",
        )
# Out:
# plot without title

# %%
# for each df in combined_pg_intensities, calculate the new column
# that contains the number of proteins in the intersection devided by the total number of proteins in the PG for each row

for(center in names(combined_pg_intensities)) {
    pg <- combined_pg_intensities[[center]]
    pg$Majority.protein.IDs <- as.character(pg$Majority.protein.IDs)
    pg$Majority.protein.IDs <- strsplit(pg$Majority.protein.IDs, ";")
    pg$Majority.P.IDs.common  <- sapply(pg$Majority.protein.IDs, function(x) length(intersect(x, common_proteins))/length(x))
    combined_pg_intensities[[center]] <- pg
}

# %%
# Calculate the percentages
percent_c1 <- combined_pg_intensities[["Center1"]] %>% 
  filter(Majority.P.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center1"]]) * 100

percent_c2 <- combined_pg_intensities[["Center2"]] %>% 
  filter(Majority.P.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center2"]]) * 100

percent_c3 <- combined_pg_intensities[["Center3"]] %>% 
  filter(Majority.P.IDs.common == 0) %>% 
  nrow() / nrow(combined_pg_intensities[["Center3"]]) * 100

# Create plots with annotations for the 0% bars
p1 <- ggplot(combined_pg_intensities[["Center1"]], aes(x=Majority.P.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center1", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c1, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center1"]], Majority.P.IDs.common == 0)) +
    theme_minimal()

p2 <- ggplot(combined_pg_intensities[["Center2"]], aes(x=Majority.P.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center2", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c2, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center2"]], Majority.P.IDs.common == 0)) +
    theme_minimal()

p3 <- ggplot(combined_pg_intensities[["Center3"]], aes(x=Majority.P.IDs.common)) +
    geom_histogram(binwidth=0.1, fill="blue", color="black") +
    labs(title="Center3", x="Proportion of common proteins in PG", y="Number of PG") +
    geom_text(aes(label=paste0(round(percent_c3, 2), "%"), y=..count..), stat="count", vjust=-0.5, data=subset(combined_pg_intensities[["Center3"]], Majority.P.IDs.common == 0)) +
    theme_minimal()

# Combine the plots
plot_grid(p1, p2, p3, labels = "AUTO", cols = 1)
# Out:
# Warning message in plot_grid(p1, p2, p3, labels = "AUTO", cols = 1):
# “Argument 'cols' is deprecated. Use 'ncol' instead.”
# Warning message:
# “The dot-dot notation (`..count..`) was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(count)` instead.”
# plot without title

# %%
nrow(combined_pg_intensities[["Center1"]])
nrow(combined_pg_intensities[["Center1"]]) - combined_pg_intensities[["Center1"]] %>% filter(Majority.P.IDs.common == 0) %>% nrow()

nrow(combined_pg_intensities[["Center2"]])
nrow(combined_pg_intensities[["Center2"]]) - combined_pg_intensities[["Center2"]] %>% filter(Majority.P.IDs.common == 0) %>% nrow()

nrow(combined_pg_intensities[["Center3"]])
nrow(combined_pg_intensities[["Center3"]]) - combined_pg_intensities[["Center3"]] %>% filter(Majority.P.IDs.common == 0) %>% nrow()
# Out:
# [1] 486
# [1] 388
# [1] 516
# [1] 391
# [1] 443
# [1] 387

# %% [markdown]
# # keep the PG if the 50% of the isoforms are inside

# %%
combined_pg_intensities_filteres <- combined_pg_intensities

for(center in names(combined_pg_intensities)) {
    pg <- combined_pg_intensities[[center]]
    print(center)
    print(nrow(pg))
    # pg <- pg %>% filter(Protein.IDs.common >= 0.5)
    # Create a new column that contain only proteins frim Proteins.IDs that are common
    pg$Protein.IDs.new_list <- sapply(pg$Protein.IDs, function(x) intersect(x, common_proteins)) 
    pg$Protein.IDs.new <- pg$Protein.IDs.new_list %>%
        sapply(function(x) paste(x, collapse = ";")) %>% as.character()
    # remove rows where the new column is empty
    pg <- pg %>% filter(pg$Protein.IDs.new != "")
    combined_pg_intensities_filteres[[center]] <- pg
    print(nrow(pg))
}
# Out:
# [1] "Center1"
# [1] 486
# [1] 398
# [1] "Center2"
# [1] 516
# [1] 399
# [1] "Center3"
# [1] 443
# [1] 390

# %%
pg_one <- unique(combined_pg_intensities_filteres[["Center1"]]$Protein.IDs.new)
length(pg_one)

pg_two <- unique(combined_pg_intensities_filteres[["Center2"]]$Protein.IDs.new)
length(pg_two)

pg_three <- unique(combined_pg_intensities_filteres[["Center3"]]$Protein.IDs.new)
length(pg_three)

intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = pg_one,
        "Center2" = pg_two,
        "Center3" = pg_three
    ),
    lwd = 2,
    filename = NULL)

grid.draw(venn_plot)
# Out:
# [1] 398
# [1] 399
# [1] 390
# [1] 275
# plot without title

# %%
pg_one <- combined_pg_intensities_filteres[["Center1"]]$Protein.IDs.new
length(pg_one)

pg_two <- combined_pg_intensities_filteres[["Center2"]]$Protein.IDs.new
length(pg_two)

pg_three <- combined_pg_intensities_filteres[["Center3"]]$Protein.IDs.new
length(pg_three)

# combine all into one list
joint_proteins <- c(pg_one, pg_two, pg_three) %>% unique()
length(joint_proteins)
# Out:
# [1] 398
# [1] 399
# [1] 390
# [1] 553

# %%
# Initialize the new data frame
result_df <- setNames(data.frame(matrix(ncol = 3, nrow = length(joint_proteins))), c("center1", "center2", "center3"))
rownames(result_df) <- joint_proteins

# Function to check intersection
check_intersection <- function(row_name, df) {
  spl_row_name <- unlist(strsplit(row_name, ";"))
  matches <- sapply(df$Protein.IDs.new, function(x) {
    length(intersect(unlist(strsplit(x, ";")), spl_row_name)) > 0
  })
  paste(df$Protein.IDs.new[matches], collapse = " | ")
}

# Fill the result data frame
for(i in 1:nrow(result_df)) {
  row_name <- rownames(result_df)[i]
  result_df[i, "center1"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center1"]])
  result_df[i, "center2"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center2"]])
  result_df[i, "center3"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center3"]])
}

# %%
# print rows from result_df where any of the columns contains " | " or empty string
result_df %>% filter(grepl(" | ", center1) | grepl(" | ", center2) | grepl(" | ", center3) | center1 == "" | center2 == "" | center3 == "")
# Out:
#                                                                                                                                                                                                                                                center1
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                                                                                                    A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                                                                                                               P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;H0YFX9;Q8IUE6;C9J386                                                                      P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;H0YFX9;Q8IUE6;C9J386
# A0A8I5KWT8;P35579;A0A8I5KZ38;P35580                                                                                                                                                                                                            A0A8I5KWT8;P35579;A0A8I5KZ38;P35580
# B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9                                                                                                                         B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9
# P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3                                                                                                                                                                                        P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3
# P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4                                                                                                                                                     P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4
# H0YAC1;P03952;E9PBC5;C9JCT1;C9J075;A0A0C4DGJ9;P20718                                                                                                                                                                                           H0YAC1;P03952;E9PBC5;C9JCT1;C9J075;A0A0C4DGJ9;P20718
# J3KP74;E9PLR3                                                                                                                                                                                                                                  J3KP74;E9PLR3
# P10909;H0YC35;H0YLK8;H0YAS8;E7ERK6;E7ETB4;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          P10909;H0YC35;H0YLK8;H0YAS8;E7ERK6;E7ETB4;E5RJZ5;E5RGB0;E5RH61;E5RG36
# P12111;C9JNG9;E7ENL6;A0A804HKQ0                                                                                                                                                                                                                P12111;C9JNG9;E7ENL6;A0A804HKQ0
# P48740;F8W876;C9JMA2                                                                                                                                                                                                                           P48740;F8W876;C9JMA2
# P63104;E7EX29;E7ESK7;E5RIR4;E9PD24;E7EVZ2;E5RGE1;B0AZS6;K7EIT4;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                P63104;E7EX29;E7ESK7;E5RIR4;E9PD24;E7EVZ2;E5RGE1;B0AZS6;K7EIT4;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258
# P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31                                                                                                                                                                  P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31
# A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1;K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9                                                                                                                                                                         A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1 | K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9
# A0A8I5KW61;P02775;P02776                                                                                                                                                                                                                       A0A8I5KW61;P02776 | P02775
# P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89                                                                                                                                                                                        P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3
# P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;C9JB55;F8WC57;CON__Q2HJF0                                                                                                                                                                                   C9JB55 | P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;F8WC57;CON__Q2HJF0
# P10909;H0YC35;H0YLK8;E7ETB4;E7ERK6;H0YAS8;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          P10909;H0YC35;H0YLK8;H0YAS8;E7ERK6;E7ETB4;E5RJZ5;E5RGB0;E5RH61;E5RG36
# P21333;Q60FE5;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2                                                                                                                                    F8WE98 | P21333;Q60FE5;A0A7P0NMY4;H0Y5C6;A0A087WWY3;A0A7I2V3E6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2
# P36955;I3L4N7;CON__Q95121;I3L4Z0;I3L4F9;I3L107;I3L2R7;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     I3L425 | P36955;I3L4N7;CON__Q95121;I3L4F9;I3L107;I3L4Z0;I3L2R7;I3L3Z3;I3L1U4
# P60709;I3L4N8;P63261;A0A804GS07;E7EVS6;A0A6Q8PFE4;A0A2R8Y793;I3L3I0;I3L1U9;Q6S8J3;A0A2R8YGF8;A0A6Q8PH58;G5E9R0;J3KT65;A5A3E0;I3L3R2;C9JUM1;C9JZR7;K7EM38;C9JTX5;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;F8WCH0;A0A7P0TBL1 P0CG38;P0CG39 | P60709;I3L4N8;P63261;E7EVS6;A0A2R8Y793;A0A804GS07;A0A6Q8PFE4;I3L3I0;I3L1U9;G5E9R0;A0A6Q8PH58;A0A2R8YGF8;C9JZR7;C9JUM1;K7EM38;I3L3R2;J3KT65;Q6S8J3;C9JTX5;A5A3E0;A0A2R8YEA7;Q562R1;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1
# P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6                                                                                                          P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4 | P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31
# P68871;A0A2R8Y7R2;F8W6P5;A0A0J9YWK4                                                                                                                                                                                                            F8W6P5 | P68871;A0A2R8Y7R2;A0A0J9YWK4
# Q04756;D6RAR4;CON__ENSEMBL:ENSBTAP00000023055                                                                                                                                                                                                  D6RAR4;CON__ENSEMBL:ENSBTAP00000023055 | Q04756
# Q92954;E9PLR3                                                                                                                                                                                                                                  J3KP74;E9PLR3 | Q92954
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                                                                                                      A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2
# A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9;P0DJI9                                                                                                                                                                                              A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9 | P0DJI9
# C9JC71;A0A8V8TN80;A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;A0A8V8TNC4;A0A8V8TNB3;H0Y4U3;A0A3B3ISU3;O75015                                                                                                                                H0Y4U3;A0A3B3ISU3;O75015 | A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;C9JC71;A0A8V8TN80;A0A8V8TNC4;A0A8V8TNB3
# C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65                                                                                                                        P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4 | P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31
# E7EX29;P63104;E5RIR4;E9PD24;E7EVZ2;E7ESK7;E5RGE1;K7EIT4;B0AZS6;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                P63104;E7EX29;E7ESK7;E5RIR4;E9PD24;E7EVZ2;E5RGE1;B0AZS6;K7EIT4;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258
# O95445;Q5SRP5                                                                                                                                                                                                                                  O95445 | Q5SRP5
# P06681;A0A0G2JL69;F2Z3N2;A0A8Q3WKN5;A0A8Q3WKM6;A0A8Q3WL70;H0Y3H6;A0A0G2JIE7;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868;A0A0G2JJ82;A0A0G2JHM4;A2ABG0;C9JYQ5;A0A0G2JI59;A0A0G2JJM0;F8WCJ9                                                 B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9 | P06681;F2Z3N2;A0A0G2JL69;A0A8Q3WKN5;A0A8Q3WKM6;A0A0G2JIE7;H0Y3H6;A0A8Q3WL70;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908;H0YFX9;Q8IUE6                                                                      P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;H0YFX9;Q8IUE6;C9J386
# P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76;B4DLR2;Q12884                                                                                                                                                                                         P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76 | Q12884;B4DLR2
# P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931                                                                                                                                                                                       P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3 | P11021;A0A7P0TB36;A0A7P0TAI0
# Q60FE5;P21333;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HJC2;A0A804HL72;A0A804HK76;O75369;Q14315                                                                                                                                    F8WE98 | P21333;Q60FE5;A0A7P0NMY4;H0Y5C6;A0A087WWY3;A0A7I2V3E6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2
# P36955;I3L4Z0;I3L4N7;CON__Q95121;I3L2R7;I3L4F9;I3L107;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     I3L425 | P36955;I3L4N7;CON__Q95121;I3L4F9;I3L107;I3L4Z0;I3L2R7;I3L3Z3;I3L1U4
# P60709;I3L4N8;P63261;E7EVS6;A0A804GS07;A0A2R8Y793;A0A6Q8PFE4;I3L3I0;I3L1U9;A0A6Q8PH58;G5E9R0;A0A2R8YGF8;C9JZR7;J3KT65;K7EM38;I3L3R2;C9JUM1;Q6S8J3;C9JTX5;A5A3E0;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1 P0CG38;P0CG39 | P60709;I3L4N8;P63261;E7EVS6;A0A2R8Y793;A0A804GS07;A0A6Q8PFE4;I3L3I0;I3L1U9;G5E9R0;A0A6Q8PH58;A0A2R8YGF8;C9JZR7;C9JUM1;K7EM38;I3L3R2;J3KT65;Q6S8J3;C9JTX5;A5A3E0;A0A2R8YEA7;Q562R1;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1
# P67936;A0A2R8YGX3;A0A2R8Y5V9;A0A2R8YE05;K7ENT6;A0A2R8YHD2;A0A2R8YEU4;P06753;A0A5F9UN72;A0A087WWU8;J3KN67;A0A2R2Y2Q3;A0A494C0P6;K7EPB9;D6R904;A0A590UK79;A0A590UJB9                                                                             A0A087WWU8;J3KN67;D6R904;A0A494C0P6;A0A2R2Y2Q3;P06753 | A0A2R8YGX3;A0A2R8Y5V9;P67936;A0A2R8YEU4;A0A2R8YE05;K7ENT6;A0A2R8YHD2;A0A590UJB9;A0A590UK79;A0A5F9UN72;K7EPB9
# P68871;A0A2R8Y7R2;F8W6P5;P02042;E9PFT6;E9PEW8;A0A0J9YWK4;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100                                                                                                                        F8W6P5 | P02042;E9PFT6;E9PEW8;C9JRG0;CON__Q3SX09;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100 | P68871;A0A2R8Y7R2;A0A0J9YWK4
# Q92954;J3KP74;E9PLR3                                                                                                                                                                                                                           J3KP74;E9PLR3 | Q92954
#                                                                                                                                                                                                                                                center2
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                                                                                                    A0A075B6P5;A0A087WW87;P01615;P01614 | A2NJV5;A0A075B6S2 | A0A0A0MRZ7;A0A075B6S6
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                                                                                                               A0A075B6R2;A0A087WW49 | P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;H0YFX9;Q8IUE6;C9J386                                                                      P20671;Q6FI13;A0A0U1RR32;A0A0U1RRH7;Q9BTM1;P04908;P0C0S8;A0A3B3IS11;Q99878;Q7L7L0;Q93077;Q96QV6;Q16777;P16104;Q96KK5;H0YFX9;Q8IUE6 | Q71UI9;P0C0S5;C9J0D1;A0A494C189;C9J386
# A0A8I5KWT8;P35579;A0A8I5KZ38;P35580                                                                                                                                                                                                            A0A8I5KWT8;P35579;A0A8I5KZ38;P35580
# B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9                                                                                                                         B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9
# P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3                                                                                                                                                                                        P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89
# P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4                                                                                                                                                     P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6
# H0YAC1;P03952;E9PBC5;C9JCT1;C9J075;A0A0C4DGJ9;P20718                                                                                                                                                                                           H0YAC1;E9PBC5;C9JCT1;C9J075 | P03952;A0A0C4DGJ9;P20718
# J3KP74;E9PLR3                                                                                                                                                                                                                                  J3KP74 | Q92954;E9PLR3
# P10909;H0YC35;H0YLK8;H0YAS8;E7ERK6;E7ETB4;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          P10909;H0YC35;H0YLK8;E7ETB4;E7ERK6;H0YAS8;E5RJZ5;E5RGB0;E5RH61;E5RG36
# P12111;C9JNG9;E7ENL6;A0A804HKQ0                                                                                                                                                                                                                C9JNG9 | P12111;E7ENL6;A0A804HKQ0
# P48740;F8W876;C9JMA2                                                                                                                                                                                                                           F8W876;C9JMA2 | P48740
# P63104;E7EX29;E7ESK7;E5RIR4;E9PD24;E7EVZ2;E5RGE1;B0AZS6;K7EIT4;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                E7EX29;P63104;P27348;B0AZS6;E7ESK7;E5RGE1;E9PD24;E7EVZ2;H0YB80;B7Z2E6;E5RIR4;E9PG15;A2IDB2;K7EIT4;I3L3T1;B4DJF2;P61981;P62258 | P31946;Q4VY20;A0A0J9YWZ2;Q4VY19;A0A0J9YWE8 | P31947
# P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31                                                                                                                                                                  P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6 | P68366;C9JEV8;C9JQ00;C9JJQ8;C9JDL2
# A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1;K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9                                                                                                                                                                         A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1;K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9
# A0A8I5KW61;P02775;P02776                                                                                                                                                                                                                       A0A8I5KW61;P02775;P02776
# P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89                                                                                                                                                                                        P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89
# P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;C9JB55;F8WC57;CON__Q2HJF0                                                                                                                                                                                   P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;C9JB55;F8WC57;CON__Q2HJF0
# P10909;H0YC35;H0YLK8;E7ETB4;E7ERK6;H0YAS8;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          P10909;H0YC35;H0YLK8;E7ETB4;E7ERK6;H0YAS8;E5RJZ5;E5RGB0;E5RH61;E5RG36
# P21333;Q60FE5;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2                                                                                                                                    P21333;Q60FE5;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2
# P36955;I3L4N7;CON__Q95121;I3L4Z0;I3L4F9;I3L107;I3L2R7;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     P36955;I3L4N7;CON__Q95121;I3L4Z0;I3L4F9;I3L107;I3L2R7;I3L3Z3;I3L425;I3L1U4
# P60709;I3L4N8;P63261;A0A804GS07;E7EVS6;A0A6Q8PFE4;A0A2R8Y793;I3L3I0;I3L1U9;Q6S8J3;A0A2R8YGF8;A0A6Q8PH58;G5E9R0;J3KT65;A5A3E0;I3L3R2;C9JUM1;C9JZR7;K7EM38;C9JTX5;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;F8WCH0;A0A7P0TBL1 P60709;I3L4N8;P63261;A0A804GS07;E7EVS6;A0A6Q8PFE4;A0A2R8Y793;I3L3I0;I3L1U9;Q6S8J3;A0A2R8YGF8;A0A6Q8PH58;G5E9R0;J3KT65;A5A3E0;I3L3R2;C9JUM1;C9JZR7;K7EM38;C9JTX5;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;F8WCH0;A0A7P0TBL1
# P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6                                                                                                          P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6
# P68871;A0A2R8Y7R2;F8W6P5;A0A0J9YWK4                                                                                                                                                                                                            P68871;A0A2R8Y7R2;F8W6P5;A0A0J9YWK4
# Q04756;D6RAR4;CON__ENSEMBL:ENSBTAP00000023055                                                                                                                                                                                                  Q04756;D6RAR4;CON__ENSEMBL:ENSBTAP00000023055
# Q92954;E9PLR3                                                                                                                                                                                                                                  Q92954;E9PLR3
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                                                                                                      A0A075B6P5;A0A087WW87;P01615;P01614 | A0A0A0MRZ7;A0A075B6S6
# A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9;P0DJI9                                                                                                                                                                                              A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9 | P0DJI9
# C9JC71;A0A8V8TN80;A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;A0A8V8TNC4;A0A8V8TNB3;H0Y4U3;A0A3B3ISU3;O75015                                                                                                                                H0Y4U3;A0A3B3ISU3;O75015 | A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;C9JC71;A0A8V8TN80;A0A8V8TNC4;A0A8V8TNB3
# C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65                                                                                                                        P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6 | P68366;C9JEV8;C9JQ00;C9JJQ8;C9JDL2
# E7EX29;P63104;E5RIR4;E9PD24;E7EVZ2;E7ESK7;E5RGE1;K7EIT4;B0AZS6;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                E7EX29;P63104;P27348;B0AZS6;E7ESK7;E5RGE1;E9PD24;E7EVZ2;H0YB80;B7Z2E6;E5RIR4;E9PG15;A2IDB2;K7EIT4;I3L3T1;B4DJF2;P61981;P62258 | P31946;Q4VY20;A0A0J9YWZ2;Q4VY19;A0A0J9YWE8 | P31947
# O95445;Q5SRP5                                                                                                                                                                                                                                  O95445 | Q5SRP5
# P06681;A0A0G2JL69;F2Z3N2;A0A8Q3WKN5;A0A8Q3WKM6;A0A8Q3WL70;H0Y3H6;A0A0G2JIE7;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868;A0A0G2JJ82;A0A0G2JHM4;A2ABG0;C9JYQ5;A0A0G2JI59;A0A0G2JJM0;F8WCJ9                                                 B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9 | P06681;F2Z3N2;A0A0G2JL69;A0A8Q3WKN5;A0A8Q3WKM6;A0A0G2JIE7;H0Y3H6;A0A8Q3WL70;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908;H0YFX9;Q8IUE6                                                                      P20671;Q6FI13;A0A0U1RR32;A0A0U1RRH7;Q9BTM1;P04908;P0C0S8;A0A3B3IS11;Q99878;Q7L7L0;Q93077;Q96QV6;Q16777;P16104;Q96KK5;H0YFX9;Q8IUE6 | Q71UI9;P0C0S5;C9J0D1;A0A494C189;C9J386
# P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76;B4DLR2;Q12884                                                                                                                                                                                         B4DLR2;Q12884 | P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76
# P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931                                                                                                                                                                                       P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89 | P11021;A0A7P0TB36;A0A7P0TAI0
# Q60FE5;P21333;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HJC2;A0A804HL72;A0A804HK76;O75369;Q14315                                                                                                                                    P21333;Q60FE5;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2
# P36955;I3L4Z0;I3L4N7;CON__Q95121;I3L2R7;I3L4F9;I3L107;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     P36955;I3L4N7;CON__Q95121;I3L4Z0;I3L4F9;I3L107;I3L2R7;I3L3Z3;I3L425;I3L1U4
# P60709;I3L4N8;P63261;E7EVS6;A0A804GS07;A0A2R8Y793;A0A6Q8PFE4;I3L3I0;I3L1U9;A0A6Q8PH58;G5E9R0;A0A2R8YGF8;C9JZR7;J3KT65;K7EM38;I3L3R2;C9JUM1;Q6S8J3;C9JTX5;A5A3E0;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1 P60709;I3L4N8;P63261;A0A804GS07;E7EVS6;A0A6Q8PFE4;A0A2R8Y793;I3L3I0;I3L1U9;Q6S8J3;A0A2R8YGF8;A0A6Q8PH58;G5E9R0;J3KT65;A5A3E0;I3L3R2;C9JUM1;C9JZR7;K7EM38;C9JTX5;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;F8WCH0;A0A7P0TBL1
# P67936;A0A2R8YGX3;A0A2R8Y5V9;A0A2R8YE05;K7ENT6;A0A2R8YHD2;A0A2R8YEU4;P06753;A0A5F9UN72;A0A087WWU8;J3KN67;A0A2R2Y2Q3;A0A494C0P6;K7EPB9;D6R904;A0A590UK79;A0A590UJB9                                                                             A0A087WWU8;A0A494C0P6;J3KN67;A0A2R2Y2Q3;P06753;D6R904 | P67936;A0A2R8YGX3;A0A2R8Y5V9;A0A2R8YE05;K7ENT6;A0A5F9UN72;A0A2R8YEU4;A0A2R8YHD2;K7EPB9;A0A590UJB9;A0A590UK79
# P68871;A0A2R8Y7R2;F8W6P5;P02042;E9PFT6;E9PEW8;A0A0J9YWK4;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100                                                                                                                        P02042;E9PFT6;E9PEW8;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100 | P68871;A0A2R8Y7R2;F8W6P5;A0A0J9YWK4
# Q92954;J3KP74;E9PLR3                                                                                                                                                                                                                           J3KP74 | Q92954;E9PLR3
#                                                                                                                                                                                                                                                center3
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                                                                                                    A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6 | A2NJV5;A0A075B6S2
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                                                                                                               P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;H0YFX9;Q8IUE6;C9J386                                                                      P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908;H0YFX9;Q8IUE6
# A0A8I5KWT8;P35579;A0A8I5KZ38;P35580                                                                                                                                                                                                            A0A8I5KWT8;P35579 | A0A8I5KZ38;P35580
# B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9;A0A0G2JHM4;A0A0G2JJ82;A0A0G2JI59;C9JYQ5;A2ABG0;A0A0G2JJM0;F8WCJ9                                                                                                                         B4E1Z4;P00751;H7C5H1;A0A8V8TNU0;A0A0G2JH38;A0A8V8TMI9 | P06681;A0A0G2JL69;F2Z3N2;A0A8Q3WKN5;A0A8Q3WKM6;A0A8Q3WL70;H0Y3H6;A0A0G2JIE7;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868;A0A0G2JJ82;A0A0G2JHM4;A2ABG0;C9JYQ5;A0A0G2JI59;A0A0G2JJM0;F8WCJ9
# P11142;P54652;E9PKE3;E9PI65;E9PN89;E9PLF4;P34931;Q53FA3                                                                                                                                                                                        E9PN89;E9PKE3;P54652;P11142 | P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931
# P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2;F8VVB9;F8VX09;F8VWV9;F8VRZ4;F8VS66;F8VQQ4                                                                                                                                                     C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65 | P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2
# H0YAC1;P03952;E9PBC5;C9JCT1;C9J075;A0A0C4DGJ9;P20718                                                                                                                                                                                           H0YAC1;P03952;E9PBC5;C9JCT1;C9J075;A0A0C4DGJ9;P20718
# J3KP74;E9PLR3                                                                                                                                                                                                                                  Q92954;J3KP74;E9PLR3
# P10909;H0YC35;H0YLK8;H0YAS8;E7ERK6;E7ETB4;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          E5RH61 | P10909;H0YLK8;H0YC35;E7ERK6;E7ETB4;H0YAS8;E5RJZ5;E5RGB0;E5RG36
# P12111;C9JNG9;E7ENL6;A0A804HKQ0                                                                                                                                                                                                                C9JNG9 | P12111;A0A804HKQ0;E7ENL6
# P48740;F8W876;C9JMA2                                                                                                                                                                                                                           F8W876;C9JMA2 | P48740
# P63104;E7EX29;E7ESK7;E5RIR4;E9PD24;E7EVZ2;E5RGE1;B0AZS6;K7EIT4;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                E7EX29;P63104;E5RIR4;E9PD24;E7EVZ2;E7ESK7;E5RGE1;K7EIT4;B0AZS6;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258
# P68366;C9JEV8;C9JQ00;C9JJQ8;A0A7P0T945;C9J2C0;Q9NY65;C9K0S6;C9JDL2;A0A7P0TA31                                                                                                                                                                  C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65
# A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1;K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9                                                                                                                                                                         A0A3B3IS80;P05062;A0A3B3ITZ0;J3QKK1;K7EKH5;C9J8F3;J3KSV6;J3QKP5;A8MVZ9
# A0A8I5KW61;P02775;P02776                                                                                                                                                                                                                       A0A8I5KW61;P02776 | P02775
# P11142;E9PKE3;P54652;E9PLF4;Q53FA3;P34931;E9PI65;E9PN89                                                                                                                                                                                        E9PN89;E9PKE3;P54652;P11142 | P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931
# P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;C9JB55;F8WC57;CON__Q2HJF0                                                                                                                                                                                   P02787;H7C5E8;C9JVG0;F8WEK9;F8WCI6;C9JB55;F8WC57;CON__Q2HJF0
# P10909;H0YC35;H0YLK8;E7ETB4;E7ERK6;H0YAS8;E5RJZ5;E5RGB0;E5RH61;E5RG36                                                                                                                                                                          E5RH61 | P10909;H0YLK8;H0YC35;E7ERK6;E7ETB4;H0YAS8;E5RJZ5;E5RGB0;E5RG36
# P21333;Q60FE5;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HL72;A0A804HK76;O75369;Q14315;A0A804HJC2                                                                                                                                    Q60FE5;P21333;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HJC2;A0A804HL72;A0A804HK76;O75369;Q14315
# P36955;I3L4N7;CON__Q95121;I3L4Z0;I3L4F9;I3L107;I3L2R7;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     P36955;I3L4Z0;I3L4N7;CON__Q95121;I3L2R7;I3L4F9;I3L107;I3L3Z3;I3L425;I3L1U4
# P60709;I3L4N8;P63261;A0A804GS07;E7EVS6;A0A6Q8PFE4;A0A2R8Y793;I3L3I0;I3L1U9;Q6S8J3;A0A2R8YGF8;A0A6Q8PH58;G5E9R0;J3KT65;A5A3E0;I3L3R2;C9JUM1;C9JZR7;K7EM38;C9JTX5;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;F8WCH0;A0A7P0TBL1 P60709;I3L4N8;P63261;E7EVS6;A0A804GS07;A0A2R8Y793;A0A6Q8PFE4;I3L3I0;I3L1U9;A0A6Q8PH58;G5E9R0;A0A2R8YGF8;C9JZR7;J3KT65;K7EM38;I3L3R2;C9JUM1;Q6S8J3;C9JTX5;A5A3E0;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1
# P68363;Q71U36;Q9BQE3;F5H5D3;P0DPH7;P0DPH8;Q6PEY2;F8VVB9;Q9NY65;C9J2C0;A0A7P0T945;F8VQQ4;F8VS66;F8VRZ4;A0A7P0TA31;F8VX09;F8VWV9;C9K0S6                                                                                                          C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65 | P0DPH8;P0DPH7;F5H5D3;Q9BQE3;Q71U36;P68363;Q6PEY2
# P68871;A0A2R8Y7R2;F8W6P5;A0A0J9YWK4                                                                                                                                                                                                            P68871;A0A2R8Y7R2;F8W6P5;P02042;E9PFT6;E9PEW8;A0A0J9YWK4;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100
# Q04756;D6RAR4;CON__ENSEMBL:ENSBTAP00000023055                                                                                                                                                                                                  D6RAR4;CON__ENSEMBL:ENSBTAP00000023055 | Q04756
# Q92954;E9PLR3                                                                                                                                                                                                                                  Q92954;J3KP74;E9PLR3
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                                                                                                      A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6
# A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9;P0DJI9                                                                                                                                                                                              A0A096LPE2;P35542;A0A3B3ISW8;E9PR14;G3V1D9;P0DJI9
# C9JC71;A0A8V8TN80;A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;A0A8V8TNC4;A0A8V8TNB3;H0Y4U3;A0A3B3ISU3;O75015                                                                                                                                C9JC71;A0A8V8TN80;A0A8V8TPL1;H0Y755;A0A8V8TNB8;A0A8V8TQ03;P08637;A0A8V8TNC4;A0A8V8TNB3;H0Y4U3;A0A3B3ISU3;O75015
# C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65                                                                                                                        C9JEV8;C9JQ00;P68366;C9JJQ8;A0A7P0T945;A0A7P0TA31;F8VVB9;F8VQQ4;F8VX09;C9K0S6;F8VS66;C9JDL2;F8VRZ4;F8VWV9;C9J2C0;Q9NY65
# E7EX29;P63104;E5RIR4;E9PD24;E7EVZ2;E7ESK7;E5RGE1;K7EIT4;B0AZS6;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258                                                                E7EX29;P63104;E5RIR4;E9PD24;E7EVZ2;E7ESK7;E5RGE1;K7EIT4;B0AZS6;A2IDB2;A0A0J9YWE8;E9PG15;Q4VY20;H0YB80;Q4VY19;I3L3T1;B7Z2E6;B4DJF2;A0A0J9YWZ2;P27348;P31946;P61981;P31947;P62258
# O95445;Q5SRP5                                                                                                                                                                                                                                  O95445;Q5SRP5
# P06681;A0A0G2JL69;F2Z3N2;A0A8Q3WKN5;A0A8Q3WKM6;A0A8Q3WL70;H0Y3H6;A0A0G2JIE7;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868;A0A0G2JJ82;A0A0G2JHM4;A2ABG0;C9JYQ5;A0A0G2JI59;A0A0G2JJM0;F8WCJ9                                                 P06681;A0A0G2JL69;F2Z3N2;A0A8Q3WKN5;A0A8Q3WKM6;A0A8Q3WL70;H0Y3H6;A0A0G2JIE7;B4DQI1;E9PDZ0;A0A8Q3WKM9;A0A0G2JK28;Q8N6L6;H0Y868;A0A0G2JJ82;A0A0G2JHM4;A2ABG0;C9JYQ5;A0A0G2JI59;A0A0G2JJM0;F8WCJ9
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908;H0YFX9;Q8IUE6                                                                      P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908;H0YFX9;Q8IUE6
# P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76;B4DLR2;Q12884                                                                                                                                                                                         P10643;A0A8Q3SIM0;CON__Q29RQ1;A0A8Q3WL76;B4DLR2;Q12884
# P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931                                                                                                                                                                                       P11021;A0A7P0TB36;A0A7P0TAI0;E9PI65;E9PLF4;Q53FA3;P34931
# Q60FE5;P21333;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HJC2;A0A804HL72;A0A804HK76;O75369;Q14315                                                                                                                                    Q60FE5;P21333;A0A7P0NMY4;A0A087WWY3;A0A7I2V3E6;F8WE98;H0Y5C6;A0A804HJC2;A0A804HL72;A0A804HK76;O75369;Q14315
# P36955;I3L4Z0;I3L4N7;CON__Q95121;I3L2R7;I3L4F9;I3L107;I3L3Z3;I3L425;I3L1U4                                                                                                                                                                     P36955;I3L4Z0;I3L4N7;CON__Q95121;I3L2R7;I3L4F9;I3L107;I3L3Z3;I3L425;I3L1U4
# P60709;I3L4N8;P63261;E7EVS6;A0A804GS07;A0A2R8Y793;A0A6Q8PFE4;I3L3I0;I3L1U9;A0A6Q8PH58;G5E9R0;A0A2R8YGF8;C9JZR7;J3KT65;K7EM38;I3L3R2;C9JUM1;Q6S8J3;C9JTX5;A5A3E0;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1 P60709;I3L4N8;P63261;E7EVS6;A0A804GS07;A0A2R8Y793;A0A6Q8PFE4;I3L3I0;I3L1U9;A0A6Q8PH58;G5E9R0;A0A2R8YGF8;C9JZR7;J3KT65;K7EM38;I3L3R2;C9JUM1;Q6S8J3;C9JTX5;A5A3E0;P0CG38;A0A2R8YEA7;Q562R1;P0CG39;F8WCH0;A0A2R8YFE2;Q9BYX7;A0A6Q8PGD7;A0A7P0TBL1
# P67936;A0A2R8YGX3;A0A2R8Y5V9;A0A2R8YE05;K7ENT6;A0A2R8YHD2;A0A2R8YEU4;P06753;A0A5F9UN72;A0A087WWU8;J3KN67;A0A2R2Y2Q3;A0A494C0P6;K7EPB9;D6R904;A0A590UK79;A0A590UJB9                                                                             P67936;A0A2R8YGX3;A0A2R8Y5V9;A0A2R8YE05;K7ENT6;A0A2R8YHD2;A0A2R8YEU4;P06753;A0A5F9UN72;A0A087WWU8;J3KN67;A0A2R2Y2Q3;A0A494C0P6;K7EPB9;D6R904;A0A590UK79;A0A590UJB9
# P68871;A0A2R8Y7R2;F8W6P5;P02042;E9PFT6;E9PEW8;A0A0J9YWK4;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100                                                                                                                        P68871;A0A2R8Y7R2;F8W6P5;P02042;E9PFT6;E9PEW8;A0A0J9YWK4;CON__Q3SX09;C9JRG0;CON__P02070;A0A2R8Y7X9;P69892;P69891;P02100
# Q92954;J3KP74;E9PLR3                                                                                                                                                                                                                           Q92954;J3KP74;E9PLR3

# %%
# write ti file
write.csv(result_df, "/home/yuliya/repos/cosybio/FedProt/data/TMT_data/balanced_data/combined/pg_merge_search/joint_proteins.csv")

# filteered
result_df %>% filter(grepl(" | ", center1) | grepl(" | ", center2) | grepl(" | ", center3) | center1 == "" | center2 == "" | center3 == "") %>%
    write.csv("/home/yuliya/repos/cosybio/FedProt/data/TMT_data/balanced_data/combined/pg_merge_search/joint_proteins_filtered.csv")

# %% [markdown]
# ## similar but with majority column

# %%
pg_one <- unique(unlist(strsplit(combined_pg_intensities[["Center1"]]$Majority.protein.IDs, ";")))
length(pg_one)

pg_two <- unique(unlist(strsplit(combined_pg_intensities[["Center2"]]$Majority.protein.IDs, ";")))
length(pg_two)

pg_three <- unique(unlist(strsplit(combined_pg_intensities[["Center3"]]$Majority.protein.IDs, ";")))
length(pg_three)

common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three) 
length(common_proteins)
# Out:
# [1] 1518
# [1] 1548
# [1] 1245
# [1] 954

# %%
combined_pg_intensities_filteres <- combined_pg_intensities

for(center in names(combined_pg_intensities)) {
    pg <- combined_pg_intensities[[center]]
    print(center)
    print(nrow(pg))
    # pg <- pg %>% filter(Protein.IDs.common >= 0.5)
    # Create a new column that contain only proteins frim Proteins.IDs that are common
    pg$Majority.protein.IDs <- as.character(pg$Majority.protein.IDs)
    pg$Majority.protein.IDs <- strsplit(pg$Majority.protein.IDs, ";")
    pg$Majority.IDs.new_list <- sapply(pg$Majority.protein.IDs, function(x) intersect(x, common_proteins)) 
    pg$Majority.IDs.new <- pg$Majority.IDs.new_list %>%
        sapply(function(x) paste(x, collapse = ";")) %>% as.character()
    # remove rows where the new column is empty
    pg <- pg %>% filter(pg$Majority.IDs.new != "")
    combined_pg_intensities_filteres[[center]] <- pg
    print(nrow(pg))
}
# Out:
# [1] "Center1"
# [1] 486
# [1] 388
# [1] "Center2"
# [1] 516
# [1] 391
# [1] "Center3"
# [1] 443
# [1] 387

# %%
pg_one <- unique(combined_pg_intensities_filteres[["Center1"]]$Majority.IDs.new)
length(pg_one)

pg_two <- unique(combined_pg_intensities_filteres[["Center2"]]$Majority.IDs.new)
length(pg_two)

pg_three <- unique(combined_pg_intensities_filteres[["Center3"]]$Majority.IDs.new)
length(pg_three)

# combine all into one list
joint_proteins <- c(pg_one, pg_two, pg_three) %>% unique()
length(joint_proteins)

intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = pg_one,
        "Center2" = pg_two,
        "Center3" = pg_three
    ),
    lwd = 2,
    filename = NULL)

grid.draw(venn_plot)
# Out:
# [1] 388
# [1] 391
# [1] 387
# [1] 479
# [1] 312
# plot without title

# %%
# Initialize the new data frame
result_df <- setNames(data.frame(matrix(ncol = 3, nrow = length(joint_proteins))), c("center1", "center2", "center3"))
rownames(result_df) <- joint_proteins

# Function to check intersection
check_intersection <- function(row_name, df) {
  spl_row_name <- unlist(strsplit(row_name, ";"))
  matches <- sapply(df$Majority.IDs.new, function(x) {
    length(intersect(unlist(strsplit(x, ";")), spl_row_name)) > 0
  })
  paste(df$Majority.IDs.new[matches], collapse = " | ")
}

# Fill the result data frame
for(i in 1:nrow(result_df)) {
  row_name <- rownames(result_df)[i]
  result_df[i, "center1"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center1"]])
  result_df[i, "center2"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center2"]])
  result_df[i, "center3"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center3"]])
}

# %%
# print rows from result_df where any of the columns contains " | " or empty string
result_df %>% filter(grepl(" | ", center1) | grepl(" | ", center2) | grepl(" | ", center3) | center1 == "" | center2 == "" | center3 == "")
# Out:
#                                                                                                                                                             center1
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                 A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                            P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;C9J386 P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;C9J386
# H0YAC1;P03952;E9PBC5                                                                                                                                        H0YAC1;P03952;E9PBC5
# P48740;F8W876                                                                                                                                               P48740;F8W876
# A0A8I5KW61;P02775                                                                                                                                           A0A8I5KW61 | P02775
# P68871;A0A2R8Y7R2;F8W6P5                                                                                                                                    F8W6P5 | P68871;A0A2R8Y7R2
# Q04756;D6RAR4                                                                                                                                               D6RAR4 | Q04756
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                   A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2
# O95445;Q5SRP5                                                                                                                                               O95445 | Q5SRP5
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908 P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;C9J386
# P68871;A0A2R8Y7R2;F8W6P5;P02042                                                                                                                             F8W6P5 | P02042 | P68871;A0A2R8Y7R2
#                                                                                                                                                             center2
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                 A0A075B6P5;A0A087WW87;P01615;P01614 | A2NJV5;A0A075B6S2 | A0A0A0MRZ7;A0A075B6S6
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                            A0A075B6R2;A0A087WW49 | P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;C9J386 P20671;Q6FI13;A0A0U1RR32;A0A0U1RRH7;Q9BTM1;P04908;P0C0S8;A0A3B3IS11;Q99878;Q7L7L0;Q93077;Q96QV6;Q16777;P16104;Q96KK5 | Q71UI9;P0C0S5;C9J0D1;A0A494C189;C9J386
# H0YAC1;P03952;E9PBC5                                                                                                                                        H0YAC1;E9PBC5 | P03952
# P48740;F8W876                                                                                                                                               F8W876 | P48740
# A0A8I5KW61;P02775                                                                                                                                           A0A8I5KW61;P02775
# P68871;A0A2R8Y7R2;F8W6P5                                                                                                                                    P68871;A0A2R8Y7R2;F8W6P5
# Q04756;D6RAR4                                                                                                                                               Q04756;D6RAR4
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                   A0A075B6P5;A0A087WW87;P01615;P01614 | A0A0A0MRZ7;A0A075B6S6
# O95445;Q5SRP5                                                                                                                                               O95445 | Q5SRP5
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908 P20671;Q6FI13;A0A0U1RR32;A0A0U1RRH7;Q9BTM1;P04908;P0C0S8;A0A3B3IS11;Q99878;Q7L7L0;Q93077;Q96QV6;Q16777;P16104;Q96KK5 | Q71UI9;P0C0S5;C9J0D1;A0A494C189;C9J386
# P68871;A0A2R8Y7R2;F8W6P5;P02042                                                                                                                             P02042 | P68871;A0A2R8Y7R2;F8W6P5
#                                                                                                                                                             center3
# A0A075B6P5;A0A087WW87;P01615;P01614;A2NJV5;A0A0A0MRZ7;A0A075B6S6;A0A075B6S2                                                                                 A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6 | A2NJV5;A0A075B6S2
# P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4                                                            P0DP08;P0DP06;A0A0C4DH41;P01825;P06331;P01824;A0A0J9YWU9;A0A087WW49;A0A075B6R2;P0DP07;A0A087WSY4
# P04908;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;C9J0D1;A0A494C189;Q96KK5;Q6FI13;P16104;Q93077;Q7L7L0;P20671;Q71UI9;Q99878;P0C0S8;Q9BTM1;Q16777;P0C0S5;C9J386 P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908
# H0YAC1;P03952;E9PBC5                                                                                                                                        H0YAC1;P03952;E9PBC5
# P48740;F8W876                                                                                                                                               F8W876 | P48740
# A0A8I5KW61;P02775                                                                                                                                           A0A8I5KW61 | P02775
# P68871;A0A2R8Y7R2;F8W6P5                                                                                                                                    P68871;A0A2R8Y7R2;F8W6P5;P02042
# Q04756;D6RAR4                                                                                                                                               D6RAR4 | Q04756
# A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6                                                                                                   A0A075B6P5;A0A087WW87;P01615;P01614;A0A0A0MRZ7;A0A075B6S6
# O95445;Q5SRP5                                                                                                                                               O95445;Q5SRP5
# P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908 P0C0S5;Q71UI9;C9J0D1;A0A494C189;C9J386;Q96QV6;A0A0U1RR32;A0A3B3IS11;A0A0U1RRH7;Q99878;Q7L7L0;P16104;P20671;Q93077;Q6FI13;P0C0S8;Q16777;Q9BTM1;Q96KK5;P04908
# P68871;A0A2R8Y7R2;F8W6P5;P02042                                                                                                                             P68871;A0A2R8Y7R2;F8W6P5;P02042

# %% [markdown]
# ## Similar using FASTA header

# %%
for(center in names(combined_pg_intensities)) {
    # replace the empty strings in Fasta.headers with values from Majority.protein.IDs    
    pg <- combined_pg_intensities[[center]]
    pg$Fasta.headers <- ifelse(pg$Fasta.headers == "", pg$Majority.protein.IDs, pg$Fasta.headers)
    combined_pg_intensities[[center]] <- pg
}

# %%
pg_one <- unique(unlist(strsplit(combined_pg_intensities[["Center1"]]$Fasta.headers, ";")))
length(pg_one)

pg_two <- unique(unlist(strsplit(combined_pg_intensities[["Center2"]]$Fasta.headers, ";")))
length(pg_two)

pg_three <- unique(unlist(strsplit(combined_pg_intensities[["Center3"]]$Fasta.headers, ";")))
length(pg_three)

common_proteins <- intersect(pg_one, pg_two) %>% intersect(pg_three) 
length(common_proteins)
# Out:
# [1] 539
# [1] 571
# [1] 497
# [1] 412

# %%
combined_pg_intensities_filteres <- combined_pg_intensities

for(center in names(combined_pg_intensities)) {
    pg <- combined_pg_intensities[[center]]
    print(center)
    pg <- pg %>% filter(pg$Fasta.headers != "")
    print(nrow(pg))
    # pg <- pg %>% filter(Protein.IDs.common >= 0.5)
    # Create a new column that contain only proteins frim Proteins.IDs that are common
    # pg$Fasta.headers <- as.character(pg$Fasta.headers)
    pg$Fasta.headers <-sapply(pg$Fasta.headers, function(x) unique(unlist(strsplit(x, ";"))))
    # remove "" from the list
    pg$Fasta.headers <- sapply(pg$Fasta.headers, function(x) x[x != ""])  
    pg$Fasta.headers.new_list <- sapply(pg$Fasta.headers, function(x) intersect(x, common_proteins)) 
    pg$Fasta.headers.new <- pg$Fasta.headers.new_list %>%
        sapply(function(x) paste(x, collapse = ";")) %>% as.character()
    # remove rows where the new column is empty
    pg <- pg %>% filter(pg$Fasta.headers.new != "")
    combined_pg_intensities_filteres[[center]] <- pg
    print(nrow(pg))
}
# Out:
# [1] "Center1"
# [1] 486
# [1] 396
# [1] "Center2"
# [1] 516
# [1] 397
# [1] "Center3"
# [1] 443
# [1] 393

# %%
pg_one <- unique(combined_pg_intensities_filteres[["Center1"]]$Fasta.headers.new)
# print(length(combined_pg_intensities_filteres[["Center1"]]$Fasta.headers.new))
length(pg_one)

pg_two <- unique(combined_pg_intensities_filteres[["Center2"]]$Fasta.headers.new)
length(pg_two)

pg_three <- unique(combined_pg_intensities_filteres[["Center3"]]$Fasta.headers.new)
length(pg_three)

# combine all into one list
joint_proteins <- c(pg_one, pg_two, pg_three) %>% unique()
length(joint_proteins)

intersect(pg_one, pg_two) %>% intersect(pg_three) %>% length()

# plot venn  diagram
grid.newpage()

venn_plot <- venn.diagram(
    x = list(
        "Center1" = pg_one,
        "Center2" = pg_two,
        "Center3" = pg_three
    ),
    lwd = 2,
    filename = NULL)

grid.draw(venn_plot)
# Out:
# [1] 375
# [1] 377
# [1] 374
# [1] 384
# [1] 367
# plot without title

# %%
# Initialize the new data frame
result_df <- setNames(data.frame(matrix(ncol = 3, nrow = length(joint_proteins))), c("center1", "center2", "center3"))
rownames(result_df) <- joint_proteins

# Function to check intersection
check_intersection <- function(row_name, df) {
  spl_row_name <- unlist(strsplit(row_name, ";"))
  matches <- sapply(df$Fasta.headers.new, function(x) {
    length(intersect(unlist(strsplit(x, ";")), spl_row_name)) > 0
  })
  paste(df$Fasta.headers.new[matches], collapse = " | ")
}

# Fill the result data frame
for(i in 1:nrow(result_df)) {
  row_name <- rownames(result_df)[i]
  result_df[i, "center1"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center1"]])
  result_df[i, "center2"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center2"]])
  result_df[i, "center3"] <- check_intersection(row_name, combined_pg_intensities_filteres[["Center3"]])
}

# %%
# print rows from result_df where any of the columns contains " | " or empty string
result_df %>% filter(grepl(" | ", center1) | grepl(" | ", center2) | grepl(" | ", center3) | center1 == "" | center2 == "" | center3 == "")
# Out:
#                                                                                                     center1
# IGLV3                                                                                               IGLV3 | IGLV3
# IGKV2;IGKV2D                                                                                        IGKV2;IGKV2D
# SAA2;SAA4                                                                                           SAA2;SAA4 | SAA2
# IGKV3D                                                                                              IGKV3D | IGKV3D | IGKV3D
# IGHV3                                                                                               IGHV3 | IGHV3 | IGHV3;IGHV3OR16 | IGHV3 | IGHV3 | IGHV3 | IGHV3
# IGHV3;IGHV3OR16                                                                                     IGHV3 | IGHV3 | IGHV3;IGHV3OR16 | IGHV3 | IGHV3 | IGHV3 | IGHV3
# IGHV4                                                                                               IGHV4
# H2AC4;H2AC1;hCG_2039566;H2AZ2;H2AZ1;H2AC12;H2AC18;H2AX;H2AC6;H2AC25;H2AC7;H2AC14;H2AC11;H2AJ;H2AC20 H2AC4;H2AC1;hCG_2039566;H2AZ2;H2AZ1;H2AC12;H2AC18;H2AX;H2AC6;H2AC25;H2AC7;H2AC14;H2AC11;H2AJ;H2AC20
# ITIH4                                                                                               ITIH4 | ITIH4 | ITIH4
# TF                                                                                                  TF | TF
# HGFAC                                                                                               HGFAC | HGFAC
# CP                                                                                                  CP | CP
# TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E                                                           TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E
# HBB                                                                                                 HBB | HBB
# FLNA                                                                                                FLNA | FLNA
# KLKB1                                                                                               KLKB1
# SERPINF1                                                                                            SERPINF1 | SERPINF1
# PRG4                                                                                                PRG4 | PRG4
# APOC4;APOC2                                                                                         APOC4;APOC2 | APOC4
# C3                                                                                                  C3 | C3
# APOM                                                                                                APOM | APOM
# AMBP                                                                                                AMBP | AMBP
# GSN                                                                                                 GSN | GSN
# SAA2                                                                                                SAA2;SAA4 | SAA2
# CLU                                                                                                 CLU
# COL6A3                                                                                              COL6A3
# MASP1                                                                                               MASP1
# APOC4                                                                                               APOC4;APOC2 | APOC4
# IGHV3OR16                                                                                           IGHV3;IGHV3OR16
# TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E                                                           TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E
# TUBA4A;TUBA1B;TUBA1A;TUBA1C                                                                         TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E | TUBA4A
# H2AZ1;H2AZ2;H2AC1;hCG_2039566;H2AC14;H2AC25;H2AX;H2AC7;H2AC6;H2AC18;H2AC11;H2AC20;H2AJ;H2AC12;H2AC4 H2AC4;H2AC1;hCG_2039566;H2AZ2;H2AZ1;H2AC12;H2AC18;H2AX;H2AC6;H2AC25;H2AC7;H2AC14;H2AC11;H2AJ;H2AC20
# HBB;HBD                                                                                             HBB | HBD | HBB
#                                                                                                     center2
# IGLV3                                                                                               IGLV3 | IGLV3 | IGLV3
# IGKV2;IGKV2D                                                                                        IGKV2;IGKV2D | IGKV2;IGKV2D | IGKV2;IGKV2D
# SAA2;SAA4                                                                                           SAA2;SAA4 | SAA2
# IGKV3D                                                                                              IGKV3D
# IGHV3                                                                                               IGHV3 | IGHV3 | IGHV3 | IGHV3 | IGHV3;IGHV3OR16
# IGHV3;IGHV3OR16                                                                                     IGHV3OR16 | IGHV3 | IGHV3 | IGHV3 | IGHV3 | IGHV3;IGHV3OR16
# IGHV4                                                                                               IGHV4 | IGHV4
# H2AC4;H2AC1;hCG_2039566;H2AZ2;H2AZ1;H2AC12;H2AC18;H2AX;H2AC6;H2AC25;H2AC7;H2AC14;H2AC11;H2AJ;H2AC20 H2AC7;H2AC18;hCG_2039566;H2AJ;H2AC4;H2AC11;H2AC14;H2AC25;H2AC6;H2AC1;H2AC20;H2AX;H2AC12 | H2AZ2;H2AZ1
# ITIH4                                                                                               ITIH4 | ITIH4 | ITIH4
# TF                                                                                                  TF
# HGFAC                                                                                               HGFAC
# CP                                                                                                  CP | CP
# TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E                                                           TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E
# HBB                                                                                                 HBB
# FLNA                                                                                                FLNA
# KLKB1                                                                                               KLKB1 | KLKB1
# SERPINF1                                                                                            SERPINF1
# PRG4                                                                                                PRG4 | PRG4
# APOC4;APOC2                                                                                         APOC4;APOC2 | APOC4
# C3                                                                                                  C3 | C3
# APOM                                                                                                APOM | APOM
# AMBP                                                                                                AMBP | AMBP
# GSN                                                                                                 GSN | GSN | GSN
# SAA2                                                                                                SAA2;SAA4 | SAA2
# CLU                                                                                                 CLU
# COL6A3                                                                                              COL6A3 | COL6A3
# MASP1                                                                                               MASP1 | MASP1
# APOC4                                                                                               APOC4;APOC2 | APOC4
# IGHV3OR16                                                                                           IGHV3OR16 | IGHV3;IGHV3OR16
# TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E                                                           TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E
# TUBA4A;TUBA1B;TUBA1A;TUBA1C                                                                         TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E | TUBA4A
# H2AZ1;H2AZ2;H2AC1;hCG_2039566;H2AC14;H2AC25;H2AX;H2AC7;H2AC6;H2AC18;H2AC11;H2AC20;H2AJ;H2AC12;H2AC4 H2AC7;H2AC18;hCG_2039566;H2AJ;H2AC4;H2AC11;H2AC14;H2AC25;H2AC6;H2AC1;H2AC20;H2AX;H2AC12 | H2AZ2;H2AZ1
# HBB;HBD                                                                                             HBD | HBB
#                                                                                                     center3
# IGLV3                                                                                               IGLV3 | IGLV3
# IGKV2;IGKV2D                                                                                        IGKV2;IGKV2D | IGKV2;IGKV2D
# SAA2;SAA4                                                                                           SAA2;SAA4
# IGKV3D                                                                                              IGKV3D | IGKV3D | IGKV3D
# IGHV3                                                                                               IGHV3 | IGHV3 | IGHV3;IGHV3OR16 | IGHV3 | IGHV3 | IGHV3
# IGHV3;IGHV3OR16                                                                                     IGHV3OR16 | IGHV3 | IGHV3 | IGHV3;IGHV3OR16 | IGHV3 | IGHV3 | IGHV3
# IGHV4                                                                                               IGHV4
# H2AC4;H2AC1;hCG_2039566;H2AZ2;H2AZ1;H2AC12;H2AC18;H2AX;H2AC6;H2AC25;H2AC7;H2AC14;H2AC11;H2AJ;H2AC20 H2AZ1;H2AZ2;H2AC1;hCG_2039566;H2AC14;H2AC25;H2AX;H2AC7;H2AC6;H2AC18;H2AC11;H2AC20;H2AJ;H2AC12;H2AC4
# ITIH4                                                                                               ITIH4 | ITIH4 | ITIH4
# TF                                                                                                  TF
# HGFAC                                                                                               HGFAC | HGFAC
# CP                                                                                                  CP | CP
# TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E                                                           TUBA4A;TUBA1B;TUBA1A;TUBA1C | TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E
# HBB                                                                                                 HBB;HBD
# FLNA                                                                                                FLNA
# KLKB1                                                                                               KLKB1
# SERPINF1                                                                                            SERPINF1
# PRG4                                                                                                PRG4
# APOC4;APOC2                                                                                         APOC4;APOC2 | APOC4
# C3                                                                                                  C3 | C3
# APOM                                                                                                APOM
# AMBP                                                                                                AMBP | AMBP
# GSN                                                                                                 GSN | GSN | GSN
# SAA2                                                                                                SAA2;SAA4
# CLU                                                                                                 CLU | CLU
# COL6A3                                                                                              COL6A3 | COL6A3
# MASP1                                                                                               MASP1 | MASP1
# APOC4                                                                                               APOC4;APOC2 | APOC4
# IGHV3OR16                                                                                           IGHV3OR16 | IGHV3;IGHV3OR16
# TUBA1B;TUBA1A;TUBA1C;TUBA3C;TUBA3D;TUBA3E                                                           TUBA4A;TUBA1B;TUBA1A;TUBA1C | TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E
# TUBA4A;TUBA1B;TUBA1A;TUBA1C                                                                         TUBA4A;TUBA1B;TUBA1A;TUBA1C | TUBA3D;TUBA3C;TUBA1C;TUBA1A;TUBA1B;TUBA3E
# H2AZ1;H2AZ2;H2AC1;hCG_2039566;H2AC14;H2AC25;H2AX;H2AC7;H2AC6;H2AC18;H2AC11;H2AC20;H2AJ;H2AC12;H2AC4 H2AZ1;H2AZ2;H2AC1;hCG_2039566;H2AC14;H2AC25;H2AX;H2AC7;H2AC6;H2AC18;H2AC11;H2AC20;H2AJ;H2AC12;H2AC4
# HBB;HBD                                                                                             HBB;HBD
